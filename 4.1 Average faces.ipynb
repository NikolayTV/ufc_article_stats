# %%
import sys
# appending a path
sys.path.append('Facer/')
from facer import facer
import matplotlib.pyplot as plt
# Out:
# Loading face detector and landmark prediction models...
# Done, models loaded.

# %%
path_to_images = "./data/photos/"
images = facer.load_images(path_to_images, amount=400)

# Detect landmarks for each face
landmarks, faces = facer.detect_face_landmarks(images)

# Use  the detected landmarks to create an average face
average_face = facer.create_average_face(faces, landmarks, save_image=True)

# View the composite image
plt.imshow(average_face)
plt.show()
# Out:
# Found 1515 in './data/photos/'.
# (1 / 1515): ./data/photos/1000_anfas.jpg
# (153 / 1515): ./data/photos/1138_anfas.jpg
# (305 / 1515): ./data/photos/1275_anfas.jpg
#
# Starting face landmark detection...
# Processing 400 images.
# (1 / 400): ./data/photos/1000_anfas.jpg
# (41 / 400): ./data/photos/1037_anfas.jpg
# (81 / 400): ./data/photos/1073_anfas.jpg
# (121 / 400): ./data/photos/1109_anfas.jpg
# (161 / 400): ./data/photos/1145_anfas.jpg
# (201 / 400): ./data/photos/1181_anfas.jpg
# (241 / 400): ./data/photos/1217_anfas.jpg
# (281 / 400): ./data/photos/1253_anfas.jpg
# (321 / 400): ./data/photos/128_anfas.jpg
# (361 / 400): ./data/photos/1325_anfas.jpg
# Skipped 0.2% of images.
#
# Starting face averaging for 399 faces.
# Image 1 / 399
# Image 21 / 399
# Image 41 / 399
# Image 61 / 399
# Image 81 / 399
# Image 101 / 399
# Image 121 / 399
# Image 141 / 399
# Image 161 / 399
# Image 181 / 399
# Image 201 / 399
# Image 221 / 399
# Image 241 / 399
# Image 261 / 399
# Image 281 / 399
# Image 301 / 399
# Image 321 / 399
# Image 341 / 399
# Image 361 / 399
# Image 381 / 399
# Done.

# %%
path_to_images = "./data/humans/"
images = facer.load_images(path_to_images, amount=400)

# Detect landmarks for each face
landmarks, faces = facer.detect_face_landmarks(images)

# Use  the detected landmarks to create an average face
average_face = facer.create_average_face(faces, landmarks, save_image=True)

# View the composite image
plt.imshow(average_face)
plt.show()
# Out:
# Found 1736 in './data/humans/'.
# (1 / 1736): ./data/humans/045d869b687f1e4dba80b40b2f826680.jpg
# (175 / 1736): ./data/humans/16376_1.jpg
# (349 / 1736): ./data/humans/23397_1.jpg
#
# Starting face landmark detection...
# Processing 400 images.
# (1 / 400): ./data/humans/045d869b687f1e4dba80b40b2f826680.jpg
# (41 / 400): ./data/humans/11017_1.jpg
# (81 / 400): ./data/humans/13024_1.jpg
# (121 / 400): ./data/humans/13205_1.jpg
# (161 / 400): ./data/humans/15876_1.jpg
# (201 / 400): ./data/humans/18318_1.jpg
# (241 / 400): ./data/humans/20322_1.jpg
# (281 / 400): ./data/humans/22472_1.jpg
# (321 / 400): ./data/humans/23290_1.jpg
# (361 / 400): ./data/humans/23429_1.jpg
# Skipped 1.5% of images.
#
# Starting face averaging for 394 faces.
# Image 1 / 394
# Image 21 / 394
# Image 41 / 394
# Image 61 / 394
# Image 81 / 394
# Image 101 / 394
# Image 121 / 394
# Image 141 / 394
# Image 161 / 394
# Image 181 / 394
# Image 201 / 394
# Image 221 / 394
# Image 241 / 394
# Image 261 / 394
# Image 281 / 394
# Image 301 / 394
# Image 321 / 394
# Image 341 / 394
# Image 361 / 394
# Image 381 / 394
# Done.
