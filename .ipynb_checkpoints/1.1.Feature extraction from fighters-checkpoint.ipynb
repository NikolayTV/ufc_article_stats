# %%
import subprocess
import shlex
import json
import pandas as pd
from glob import glob
from tqdm import tqdm_notebook as tqdm
import uuid
import os
import cv2

# %%
folder_path = 'data/photos/'
photos = os.listdir(folder_path)[:]
photo_ids = set([i.split('_')[0] for i in photos])
photo_ids
# Out:
# {'955',
#  '1202',
#  '1238',
#  '428',
#  '1449',
#  '867',
#  '242',
#  '23',
#  '81',
#  '800',
#  '803',
#  '825',
#  '1334',
#  '70',
#  '1323',
#  '1015',
#  '1430',
#  '3659',
#  '1399',
#  '294',
#  '1413',
#  '827',
#  '693',
#  '387',
#  '3427',
#  '942',
#  '514',
#  '549',
#  '702',
#  '1418',
#  '809',
#  '515',
#  '1372',
#  '369',
#  '1219',
#  '113',
#  '814',
#  '225',
#  '150',
#  '1285',
#  '1029',
#  '1325',
#  '276',
#  '697',
#  '978',
#  '466',
#  '44',
#  '1279',
#  '1131',
#  '1310',
#  '962',
#  '450',
#  '55',
#  '1163',
#  '161',
#  '1427',
#  '157',
#  '442',
#  '381',
#  '736',
#  '652',
#  '3434',
#  '167',
#  '1371',
#  '954',
#  '870',
#  '1192',
#  '682',
#  '1145',
#  '121',
#  '1273',
#  '1292',
#  '1063',
#  '1333',
#  '824',
#  '952',
#  '338',
#  '464',
#  '1076',
#  '1201',
#  '1057',
#  '712',
#  '862',
#  '3623',
#  '932',
#  '1221',
#  '706',
#  '3640',
#  '1150',
#  '176',
#  '1294',
#  '377',
#  '1085',
#  '497',
#  '759',
#  '149',
#  '495',
#  '816',
#  '993',
#  '1217',
#  '1061',
#  '1149',
#  '572',
#  '1207',
#  '1485',
#  '771',
#  '1354',
#  '1479',
#  '945',
#  '525',
#  '852',
#  '463',
#  '782',
#  '130',
#  '1141',
#  '184',
#  '370',
#  '424',
#  '1166',
#  '1363',
#  '1169',
#  '1350',
#  '1264',
#  '178',
#  '378',
#  '57',
#  '1077',
#  '543',
#  '829',
#  '663',
#  '444',
#  '1095',
#  '651',
#  '1128',
#  '1178',
#  '1119',
#  '950',
#  '419',
#  '1312',
#  '1116',
#  '1098',
#  '941',
#  '254',
#  '51',
#  '1391',
#  '537',
#  '647',
#  '912',
#  '1120',
#  '96',
#  '715',
#  '752',
#  '227',
#  '145',
#  '1171',
#  '1144',
#  '1026',
#  '2',
#  '412',
#  '622',
#  '925',
#  '3625',
#  '851',
#  '677',
#  '3646',
#  '1297',
#  '1045',
#  '1266',
#  '1013',
#  '660',
#  '1383',
#  '290',
#  '347',
#  '97',
#  '379',
#  '734',
#  '1213',
#  '607',
#  '499',
#  '1336',
#  '69',
#  '595',
#  '1147',
#  '566',
#  '1340',
#  '246',
#  '1022',
#  '147',
#  '1209',
#  '561',
#  '995',
#  '1228',
#  '120',
#  '213',
#  '102',
#  '898',
#  '583',
#  '1400',
#  '744',
#  '490',
#  '3405',
#  '105',
#  '970',
#  '1132',
#  '1331',
#  '506',
#  '42',
#  '959',
#  '9',
#  '106',
#  '1919',
#  '373',
#  '654',
#  '3392',
#  '1356',
#  '190',
#  '711',
#  '3645',
#  '1646',
#  '1394',
#  '126',
#  '430',
#  '6',
#  '762',
#  '333',
#  '1287',
#  '163',
#  '1375',
#  '219',
#  '240',
#  '529',
#  '1278',
#  '747',
#  '630',
#  '375',
#  '627',
#  '502',
#  '408',
#  '1450',
#  '1443',
#  '859',
#  '37',
#  '1379',
#  '279',
#  '983',
#  '530',
#  '848',
#  '79',
#  '974',
#  '1123',
#  '1268',
#  '1230',
#  '449',
#  '946',
#  '580',
#  '1381',
#  '872',
#  '1918',
#  '1314',
#  '212',
#  '1912',
#  '3396',
#  '13',
#  '1222',
#  '889',
#  '883',
#  '1260',
#  '493',
#  '169',
#  '961',
#  '657',
#  '1369',
#  '1417',
#  '30',
#  '1828',
#  '1602',
#  '746',
#  '1068',
#  '1263',
#  '82',
#  '1024',
#  '310',
#  '1195',
#  '469',
#  '452',
#  '562',
#  '366',
#  '1087',
#  '454',
#  '857',
#  '248',
#  '1035',
#  '1016',
#  '87',
#  '301',
#  '22',
#  '874',
#  '837',
#  '237',
#  '283',
#  '140',
#  '162',
#  '467',
#  '429',
#  '926',
#  '313',
#  '196',
#  '672',
#  '132',
#  '508',
#  '1091',
#  '1939',
#  '653',
#  '906',
#  '436',
#  '1311',
#  '168',
#  '286',
#  '535',
#  '1102',
#  '532',
#  '745',
#  '847',
#  '966',
#  '1146',
#  '89',
#  '1444',
#  '1081',
#  '701',
#  '390',
#  '838',
#  '850',
#  '1036',
#  '964',
#  '3649',
#  '998',
#  '1295',
#  '1010',
#  '434',
#  '63',
#  '1190',
#  '721',
#  '143',
#  '325',
#  '509',
#  '905',
#  '1423',
#  '1378',
#  '951',
#  '1290',
#  '922',
#  '1107',
#  '448',
#  '831',
#  '1243',
#  '940',
#  '3638',
#  '1065',
#  '93',
#  '207',
#  '631',
#  '920',
#  '1072',
#  '524',
#  '3619',
#  '854',
#  '981',
#  '1184',
#  '739',
#  '127',
#  '494',
#  '1353',
#  '253',
#  '1025',
#  '95',
#  '483',
#  '892',
#  '311',
#  '1395',
#  '28',
#  '139',
#  '1272',
#  '1315',
#  '1088',
#  '761',
#  '1384',
#  '1276',
#  '1385',
#  '3654',
#  '374',
#  '557',
#  '555',
#  '472',
#  '876',
#  '723',
#  '3636',
#  '146',
#  '3531',
#  '1926',
#  '262',
#  '1439',
#  '241',
#  '608',
#  '780',
#  '1130',
#  '1270',
#  '641',
#  '252',
#  '1267',
#  '407',
#  '451',
#  '45',
#  '575',
#  '206',
#  '43',
#  '1114',
#  '1212',
#  '198',
#  '1197',
#  '360',
#  '18',
#  '760',
#  '1044',
#  '1406',
#  '275',
#  '164',
#  '298',
#  '180',
#  '295',
#  '456',
#  '1031',
#  '853',
#  '949',
#  '209',
#  '459',
#  '1237',
#  '453',
#  '255',
#  '626',
#  '94',
#  '1362',
#  '230',
#  '1175',
#  '649',
#  '517',
#  '492',
#  '1351',
#  '540',
#  '908',
#  '3628',
#  '553',
#  '346',
#  '1099',
#  '289',
#  '598',
#  '923',
#  '728',
#  '1189',
#  '3648',
#  '385',
#  '343',
#  '858',
#  '1414',
#  '918',
#  '92',
#  '805',
#  '716',
#  '75',
#  '362',
#  '601',
#  '1137',
#  '265',
#  '724',
#  '394',
#  '763',
#  '1153',
#  '108',
#  '914',
#  '582',
#  '187',
#  '11',
#  '968',
#  '1792',
#  '1338',
#  '988',
#  '842',
#  '1124',
#  '1083',
#  '605',
#  '1277',
#  '963',
#  '1005',
#  '1442',
#  '856',
#  '258',
#  '220',
#  '683',
#  '1203',
#  '980',
#  '512',
#  '368',
#  '303',
#  '527',
#  '1778',
#  '987',
#  '460',
#  '1139',
#  '402',
#  '1426',
#  '1104',
#  '288',
#  '1298',
#  '1328',
#  '789',
#  '48',
#  '326',
#  '1386',
#  '406',
#  '404',
#  '1021',
#  '1191',
#  '569',
#  '323',
#  '1048',
#  '1071',
#  '46',
#  '989',
#  '801',
#  '203',
#  '768',
#  '215',
#  '201',
#  '685',
#  '361',
#  '691',
#  '919',
#  '890',
#  '438',
#  '587',
#  '401',
#  '1007',
#  '1594',
#  '420',
#  '1097',
#  '757',
#  '60',
#  '1244',
#  '1062',
#  '1488',
#  '335',
#  '110',
#  '1320',
#  '367',
#  '340',
#  '507',
#  '1239',
#  '4',
#  '1172',
#  '1185',
#  '769',
#  '979',
#  '1411',
#  '694',
#  '80',
#  '1410',
#  '748',
#  '1125',
#  '751',
#  '1424',
#  '559',
#  '403',
#  '175',
#  '410',
#  '533',
#  '160',
#  '994',
#  '1208',
#  '836',
#  '1330',
#  '357',
#  '1257',
#  '14',
#  '235',
#  '703',
#  '519',
#  '603',
#  '3650',
#  '1240',
#  '985',
#  '355',
#  '3637',
#  '695',
#  '924',
#  '546',
#  '352',
#  '104',
#  '1047',
#  '282',
#  '1370',
#  '984',
#  '336',
#  '680',
#  '172',
#  '675',
#  '1332',
#  '154',
#  '5',
#  '443',
#  '930',
#  '15',
#  '1220',
#  '1251',
#  '342',
#  '726',
#  '658',
#  '786',
#  '3652',
#  '1283',
#  '251',
#  '3660',
#  '182',
#  '928',
#  '199',
#  '400',
#  '191',
#  '879',
#  '1357',
#  '1373',
#  '7',
#  '372',
#  '24',
#  '52',
#  '393',
#  '1135',
#  '1160',
#  '722',
#  '586',
#  '486',
#  '91',
#  '31',
#  '1318',
#  '1194',
#  '804',
#  '36',
#  '88',
#  '477',
#  '957',
#  '1200',
#  '741',
#  '86',
#  '131',
#  '257',
#  '895',
#  '1419',
#  '996',
#  '228',
#  '792',
#  '415',
#  '305',
#  '380',
#  '521',
#  '1422',
#  '1438',
#  '39',
#  '193',
#  '1101',
#  '192',
#  '1259',
#  '321',
#  '871',
#  '1151',
#  '1110',
#  '820',
#  '211',
#  '505',
#  '1196',
#  '1923',
#  '72',
#  '109',
#  '1042',
#  '3624',
#  '1247',
#  '700',
#  '944',
#  '183',
#  '1034',
#  '1345',
#  '431',
#  '1432',
#  '1181',
#  '947',
#  '344',
#  '992',
#  '531',
#  '888',
#  '1179',
#  '135',
#  '894',
#  '1106',
#  '625',
#  '1067',
#  '138',
#  '774',
#  '1241',
#  '1140',
#  '990',
#  '568',
#  '1254',
#  '8',
#  '545',
#  '636',
#  '917',
#  '646',
#  '208',
#  '3653',
#  '1236',
#  '1066',
#  '600',
#  '629',
#  '617',
#  '364',
#  '165',
#  '671',
#  '1387',
#  '866',
#  '1033',
#  '1009',
#  '1316',
#  '425',
#  '1093',
#  '216',
#  '1489',
#  '473',
#  '1458',
#  '358',
#  '913',
#  '1214',
#  '470',
#  '550',
#  '510',
#  '1242',
#  '1393',
#  '1916',
#  '855',
#  '1329',
#  '1211',
#  '1252',
#  '560',
#  '1301',
#  '628',
#  '692',
#  '1322',
#  '656',
#  '1134',
#  '117',
#  '439',
#  '16',
#  '705',
#  '1537',
#  '1255',
#  '1374',
#  '589',
#  '938',
#  '793',
#  '1082',
#  '689',
#  '468',
#  '766',
#  '523',
#  '3656',
#  '1269',
#  '315',
#  '1392',
#  '40',
#  '1366',
#  '934',
#  '345',
#  '101',
#  '642',
#  '384',
#  '907',
#  '1080',
#  '221',
#  '427',
#  '399',
#  '465',
#  '579',
#  '916',
#  '594',
#  '676',
#  '1073',
#  '151',
#  '100',
#  '897',
#  '1731',
#  '1177',
#  '1182',
#  '349',
#  '570',
#  '1084',
#  '650',
#  '411',
#  '3630',
#  '1002',
#  '796',
#  '478',
#  '1415',
#  '875',
#  '112',
#  '83',
#  '496',
#  '47',
#  '232',
#  '217',
#  '819',
#  '274',
#  '171',
#  '1302',
#  '632',
#  '1305',
#  '1092',
#  '1390',
#  '244',
#  '1365',
#  '481',
#  '134',
#  '29',
#  '574',
#  '606',
#  '458',
#  '1069',
#  '667',
#  '1193',
#  '558',
#  '1056',
#  '1227',
#  '948',
#  '1433',
#  '939',
#  '620',
#  '1173',
#  '901',
#  '767',
#  '3642',
#  '1431',
#  '231',
#  '243',
#  '991',
#  '1046',
#  '433',
#  '1405',
#  '1352',
#  '1284',
#  '1337',
#  '1380',
#  '32',
#  '730',
#  '56',
#  '1017',
#  '122',
#  '59',
#  '239',
#  '266',
#  '259',
#  '3651',
#  '1206',
#  '328',
#  '886',
#  '740',
#  '1234',
#  '927',
#  '1396',
#  '396',
#  '1437',
#  '397',
#  '1457',
#  '556',
#  '1164',
#  '371',
#  '247',
#  '309',
#  '1282',
#  '422',
#  '137',
#  '1086',
#  '71',
#  '1142',
#  '3662',
#  '885',
#  '1368',
#  '389',
#  '1127',
#  '1162',
#  '1261',
#  '718',
#  '696',
#  '797',
#  '714',
#  '179',
#  '331',
#  '1143',
#  '645',
#  '633',
#  '953',
#  '503',
#  '602',
#  '534',
#  '673',
#  '417',
#  '1500',
#  '662',
#  '1109',
#  '3629',
#  '719',
#  '27',
#  '38',
#  '611',
#  '17',
#  '421',
#  '382',
#  '790',
#  '3470',
#  '592',
#  '911',
#  '788',
#  '564',
#  '659',
#  '1050',
#  '322',
#  '1376',
#  '982',
#  '194',
#  '111',
#  '1428',
#  '936',
#  '58',
#  '810',
#  '293',
#  '304',
#  '1349',
#  '500',
#  '1280',
#  '687',
#  '356',
#  '704',
#  '300',
#  '479',
#  '1341',
#  '513',
#  '351',
#  '1157',
#  '3395',
#  '249',
#  '526',
#  '292',
#  '1041',
#  '817',
#  '1112',
#  '616',
#  '596',
#  '640',
#  '3615',
#  '1049',
#  '610',
#  '98',
#  '1218',
#  '670',
#  '1216',
#  '1126',
#  '376',
#  '363',
#  '1040',
#  '688',
#  '49',
#  '1308',
#  '1339',
#  '1408',
#  '1018',
#  '737',
#  '756',
#  '833',
#  '1389',
#  '173',
#  '1299',
#  '794',
#  '1038',
#  '1425',
#  '62',
#  '222',
#  '830',
#  '1168',
#  '1186',
#  '330',
#  '285',
#  '877',
#  '1043',
#  '166',
#  '1159',
#  '1152',
#  '354',
#  ...}

# %%
# Reformat all files to .jpg
# for i in tqdm(glob('data/photos/*')):
#     try:
#         img = cv2.imread(i)
#         img.shape
#         os.remove(i)
#         new_name = i.split('.')[0]+'.jpg'
#         cv2.imwrite(new_name, img)
#     except:
#         print(i)

# %%
folder_path = 'data/photos/*'
photos = glob(folder_path)

merlin_feature_keys = ['Асимметрия челюсти', 'Высота бровей', 'Наклон глаз', 'Полнота верхней губы', 'Полнота нижней губы', 'Асимметрия размера глаз', 'Ширина посадки глаз', 'Скулы', 'Форма головы', 'Верхнее веко', 'Асимметрия брови', 'Наклон бровей', 'Размер рта', 'Асимметрия наклона глаз', 'Асимметрия носа', 'Размер глаз', 'Оттопыренность ушей', 'Ширина челюсти', 'Уголки рта', 'Форма бровей']

merlin_feature_cat_keys = [i + ' cat' for i in merlin_feature_keys] 
df = pd.DataFrame(columns=merlin_feature_keys + merlin_feature_cat_keys +
                  ['anfas_bbox', 'anfas_roll', 'anfas_pitch', 'anfas_yaw', 'anfas_keypoints'])

# for col in ['anfas_bbox', 'anfas_keypoints']:
#     df[col] = df[col].astype('object')

df
# Out:
# Empty DataFrame
# Columns: [Асимметрия челюсти, Высота бровей, Наклон глаз, Полнота верхней губы, Полнота нижней губы, Асимметрия размера глаз, Ширина посадки глаз, Скулы, Форма головы, Верхнее веко, Асимметрия брови, Наклон бровей, Размер рта, Асимметрия наклона глаз, Асимметрия носа, Размер глаз, Оттопыренность ушей, Ширина челюсти, Уголки рта, Форма бровей, Асимметрия челюсти cat, Высота бровей cat, Наклон глаз cat, Полнота верхней губы cat, Полнота нижней губы cat, Асимметрия размера глаз cat, Ширина посадки глаз cat, Скулы cat, Форма головы cat, Верхнее веко cat, Асимметрия брови cat, Наклон бровей cat, Размер рта cat, Асимметрия наклона глаз cat, Асимметрия носа cat, Размер глаз cat, Оттопыренность ушей cat, Ширина челюсти cat, Уголки рта cat, Форма бровей cat, anfas_bbox, anfas_roll, anfas_pitch, anfas_yaw, anfas_keypoints]
# Index: []
#
# [0 rows x 45 columns]

# %%
for i in range(4000):
    photos = {}
    anfas_path = f'data/photos/{i}_anfas.jpg'
    
    if os.path.exists(anfas_path):
        df.loc[i, 'anfas_path'] = anfas_path
        
        
df
# Out:
#      Асимметрия челюсти Высота бровей Наклон глаз Полнота верхней губы  \
# 1                   NaN           NaN         NaN                  NaN
# 2                   NaN           NaN         NaN                  NaN
# 3                   NaN           NaN         NaN                  NaN
# 4                   NaN           NaN         NaN                  NaN
# 5                   NaN           NaN         NaN                  NaN
# ...                 ...           ...         ...                  ...
# 3656                NaN           NaN         NaN                  NaN
# 3659                NaN           NaN         NaN                  NaN
# 3660                NaN           NaN         NaN                  NaN
# 3662                NaN           NaN         NaN                  NaN
# 3663                NaN           NaN         NaN                  NaN
#
#      Полнота нижней губы Асимметрия размера глаз Ширина посадки глаз Скулы  \
# 1                    NaN                     NaN                 NaN   NaN
# 2                    NaN                     NaN                 NaN   NaN
# 3                    NaN                     NaN                 NaN   NaN
# 4                    NaN                     NaN                 NaN   NaN
# 5                    NaN                     NaN                 NaN   NaN
# ...                  ...                     ...                 ...   ...
# 3656                 NaN                     NaN                 NaN   NaN
# 3659                 NaN                     NaN                 NaN   NaN
# 3660                 NaN                     NaN                 NaN   NaN
# 3662                 NaN                     NaN                 NaN   NaN
# 3663                 NaN                     NaN                 NaN   NaN
#
#      Форма головы Верхнее веко  ... Оттопыренность ушей cat  \
# 1             NaN          NaN  ...                     NaN
# 2             NaN          NaN  ...                     NaN
# 3             NaN          NaN  ...                     NaN
# 4             NaN          NaN  ...                     NaN
# 5             NaN          NaN  ...                     NaN
# ...           ...          ...  ...                     ...
# 3656          NaN          NaN  ...                     NaN
# 3659          NaN          NaN  ...                     NaN
# 3660          NaN          NaN  ...                     NaN
# 3662          NaN          NaN  ...                     NaN
# 3663          NaN          NaN  ...                     NaN
#
#      Ширина челюсти cat Уголки рта cat Форма бровей cat anfas_bbox anfas_roll  \
# 1                   NaN            NaN              NaN        NaN        NaN
# 2                   NaN            NaN              NaN        NaN        NaN
# 3                   NaN            NaN              NaN        NaN        NaN
# 4                   NaN            NaN              NaN        NaN        NaN
# 5                   NaN            NaN              NaN        NaN        NaN
# ...                 ...            ...              ...        ...        ...
# 3656                NaN            NaN              NaN        NaN        NaN
# 3659                NaN            NaN              NaN        NaN        NaN
# 3660                NaN            NaN              NaN        NaN        NaN
# 3662                NaN            NaN              NaN        NaN        NaN
# 3663                NaN            NaN              NaN        NaN        NaN
#
#      anfas_pitch anfas_yaw anfas_keypoints                  anfas_path
# 1            NaN       NaN             NaN     data/photos/1_anfas.jpg
# 2            NaN       NaN             NaN     data/photos/2_anfas.jpg
# 3            NaN       NaN             NaN     data/photos/3_anfas.jpg
# 4            NaN       NaN             NaN     data/photos/4_anfas.jpg
# 5            NaN       NaN             NaN     data/photos/5_anfas.jpg
# ...          ...       ...             ...                         ...
# 3656         NaN       NaN             NaN  data/photos/3656_anfas.jpg
# 3659         NaN       NaN             NaN  data/photos/3659_anfas.jpg
# 3660         NaN       NaN             NaN  data/photos/3660_anfas.jpg
# 3662         NaN       NaN             NaN  data/photos/3662_anfas.jpg
# 3663         NaN       NaN             NaN  data/photos/3663_anfas.jpg
#
# [1515 rows x 46 columns]

# %%
def parse_new_merlin_features(response):
    anfas_json = {}
    if len(response['anfas_glazomer']) > 0:
        for feature_item in response['anfas_glazomer']['feature_values'].items():
            key = feature_item[0]
            value = feature_item[1]
            anfas_json[key] = value
            
    return anfas_json

def parse_new_merlin_features_cat(response):
    anfas_json = {}
    if len(response['anfas_glazomer']) > 0:
        for feature_item in response['anfas_glazomer']['feature_cat'].items():
            key = feature_item[0]
            value = feature_item[1]
            anfas_json[f'{key} cat'] = value
            
    return anfas_json
        
        
with open('/home/nikolay/workspace/Merlin/merlin/supl/api_feature.json') as f:
    features = json.load(f)
features
# Out:
# [{'id': '72',
#   'name': 'Профиль',
#   'values': {'240': 'Иррац', '241': 'Средний', '239': 'Рац'}},
#  {'id': '71',
#   'name': 'Затылок',
#   'values': {'238': 'Скошен', '250': 'Средний', '237': 'Выражен'}},
#  {'id': '57',
#   'name': 'Шея',
#   'values': {'206': 'Короткая', '207': 'Средняя', '208': 'Длинная'}},
#  {'id': '53',
#   'name': 'Доминирующая зона лица ',
#   'values': {'195': 'Нижняя',
#    '196': 'Средняя',
#    '197': 'Верхняя',
#    '247': 'Равнозначные',
#    '297': 'Верхняя и нижняя',
#    '298': 'Верхняя и средняя',
#    '299': 'Средняя и нижняя'}},
#  {'id': '51',
#   'name': 'Форма головы',
#   'values': {'181': 'Брахицефал', '182': 'Мезоцефал', '183': 'Долихоцефал'}},
#  {'id': '40',
#   'name': 'Линия волос',
#   'values': {'144': 'Ментально-оценочная',
#    '145': 'Ментально-системная',
#    '146': 'Телесно-оценочная',
#    '147': 'Телесно-системная'}},
#  {'id': '38',
#   'name': 'Зоны лба',
#   'values': {'135': 'Центр', '136': 'Не выражены', '137': 'Периферия'}},
#  {'id': '37',
#   'name': 'Скос лба',
#   'values': {'130': 'Скошенный',
#    '131': 'Средне-скошенный',
#    '132': 'Средне-прямой',
#    '133': 'Прямой',
#    '134': 'Выпуклый'}},
#  {'id': '36',
#   'name': 'Надбровные дуги',
#   'values': {'129': 'Выражены',
#    '128': 'Средне-выражены',
#    '127': 'Не выражены'}},
#  {'id': '35',
#   'name': 'Форма бровей',
#   'values': {'123': 'Прямые',
#    '124': 'Серпом',
#    '125': 'Изломом',
#    '126': 'Полукруглые'}},
#  {'id': '33',
#   'name': 'Высота посадки бровей',
#   'values': {'116': 'Низкие',
#    '117': 'Средне-низкие',
#    '118': 'Средние по высоте',
#    '119': 'Средне-высокие',
#    '120': 'Высокие'}},
#  {'id': '31',
#   'name': 'Густота бровей',
#   'values': {'112': 'Густые', '177': 'Cредне выражены', '113': 'Не выражены'}},
#  {'id': '77',
#   'name': 'Наклон бровей',
#   'values': {'262': 'Атакующие',
#    '308': 'Средние',
#    '261': 'Без наклона',
#    '260': 'Домиком'}},
#  {'id': '26',
#   'name': 'Размер глаз',
#   'values': {'99': 'Большие',
#    '98': 'Средне-большие',
#    '97': 'Средние',
#    '96': 'Средне-маленькие',
#    '95': 'Маленькие'}},
#  {'id': '56',
#   'name': 'Наклон глаз',
#   'values': {'204': 'Вверх', '232': 'Без наклона', '205': 'Вниз'}},
#  {'id': '27',
#   'name': 'Ширина посадки глаз',
#   'values': {'100': 'Близко посажены',
#    '101': 'Средняя посадка',
#    '102': 'Далеко посажены'}},
#  {'id': '55',
#   'name': 'Верхнее веко',
#   'values': {'201': 'Гипертонус', '203': 'Выраженные', '202': 'Опущенные'}},
#  {'id': '46',
#   'name': 'Выпуклость глаз',
#   'values': {'160': 'Выпуклые',
#    '161': 'Средне-выпуклые',
#    '313': 'Средние по выпуклости',
#    '162': 'Средне-впалые',
#    '163': 'Впалые'}},
#  {'id': '28',
#   'name': 'Глубина посадки глаз',
#   'values': {'105': 'Неглубоко', '104': 'Средне', '103': 'Глубоко '}},
#  {'id': '24',
#   'name': 'Впалость переносицы',
#   'values': {'91': 'Прямая',
#    '306': 'Средне-прямая',
#    '173': 'Cредняя',
#    '307': 'Средне-впалая',
#    '92': 'Впалая'}},
#  {'id': '17',
#   'name': 'Высота носа',
#   'values': {'63': 'Низкий',
#    '64': 'Средне-низкий',
#    '65': 'Средний по высоте',
#    '66': 'Средне-высокий',
#    '67': 'Высокий'}},
#  {'id': '19',
#   'name': 'Длина носа',
#   'values': {'73': 'Короткий',
#    '74': 'Средне-короткий',
#    '75': 'Средний по длине',
#    '76': 'Средне-длинный',
#    '77': 'Длинный'}},
#  {'id': '20',
#   'name': 'Наклон носа',
#   'values': {'80': 'Вздернутый', '79': 'Близко к среднему', '78': 'Опущеный'}},
#  {'id': '18',
#   'name': 'Ширина носа',
#   'values': {'72': 'Широкий',
#    '71': 'Средне-широкий',
#    '70': 'Средний по ширине',
#    '69': 'Средне-узкий',
#    '68': 'Узкий'}},
#  {'id': '23',
#   'name': 'Ширина переносицы',
#   'values': {'90': 'Широкая',
#    '89': 'Средне-широкая',
#    '88': 'Средняя по ширине',
#    '87': 'Средне-узкая',
#    '86': 'Узкая'}},
#  {'id': '21',
#   'name': 'Ширина ноздрей',
#   'values': {'83': 'Широкие', '82': 'Средние', '81': 'Узкие'}},
#  {'id': '39',
#   'name': 'Размер ушей',
#   'values': {'139': 'Маленькие',
#    '523': 'Средне-маленькие',
#    '141': 'Средние по размеру',
#    '524': 'Средне-большие',
#    '143': 'Большие'}},
#  {'id': '54',
#   'name': 'Оттопыренность ушей',
#   'values': {'198': 'Прижатые', '248': 'Средние', '200': 'Оттопыренные'}},
#  {'id': '25',
#   'name': 'Скулы',
#   'values': {'93': 'Выражены', '174': 'Cредне выражены', '94': 'Не выражены'}},
#  {'id': '15',
#   'name': 'Высота желобка',
#   'values': {'59': 'Высокий', '57': 'Средний по высоте', '55': 'Низкий'}},
#  {'id': '14',
#   'name': 'Ширина желобка',
#   'values': {'54': 'Широкий', '52': 'Средний по ширине', '50': 'Узкий'}},
#  {'id': '16',
#   'name': 'Глубина желобка',
#   'values': {'60': 'Отсутствует',
#    '61': 'Средний по глубине',
#    '62': 'Глубокий'}},
#  {'id': '11',
#   'name': 'Доминантность губ',
#   'values': {'42': 'Верхняя доминанта',
#    '44': 'Равнозначные',
#    '43': 'Нижняя доминанта'}},
#  {'id': '8',
#   'name': 'Размер рта',
#   'values': {'31': 'Большой',
#    '312': 'Средне-большой',
#    '29': 'Средний',
#    '311': 'Средне-маленький',
#    '27': 'Маленький'}},
#  {'id': '9',
#   'name': 'Полнота нижней губы',
#   'values': {'32': 'Тонкая',
#    '310': 'Средне-тонкая',
#    '34': 'Средняя',
#    '309': 'Средне-полная',
#    '36': 'Полная'}},
#  {'id': '10',
#   'name': 'Полнота верхней губы',
#   'values': {'41': 'Полная',
#    '317': 'Средне-полная',
#    '39': 'Средняя',
#    '318': 'Средне-тонкая',
#    '37': 'Тонкая'}},
#  {'id': '50',
#   'name': 'Контур нижней губы',
#   'values': {'178': 'Размытый', '179': 'Средне-четкий', '180': 'Четкий'}},
#  {'id': '70',
#   'name': 'Контур верхней губы',
#   'values': {'228': 'Размытый', '229': 'Средне-четкий', '230': 'Четкий'}},
#  {'id': '78',
#   'name': 'Уголки губ',
#   'values': {'263': 'Уголки вниз',
#    '265': 'Уголки прямые',
#    '264': 'Уголки вверх'}},
#  {'id': '1',
#   'name': 'Ширина челюсти',
#   'values': {'1': 'Узкая',
#    '2': 'Средне-узкая',
#    '3': 'Средняя по ширине',
#    '4': 'Средне-широкая',
#    '5': 'Широкая'}},
#  {'id': '4',
#   'name': 'Угол челюсти',
#   'values': {'17': 'Прямой',
#    '16': 'Средне-прямой',
#    '15': 'Плавный',
#    '14': 'Отсутствует'}},
#  {'id': '2',
#   'name': 'Тяжесть челюсти',
#   'values': {'10': 'Тяжелая',
#    '9': 'Средне-тяжелая',
#    '8': 'Средняя по тяжести',
#    '7': 'Средне-легкая',
#    '6': 'Легкая'}},
#  {'id': '3',
#   'name': 'Выдвинутость челюсти',
#   'values': {'13': 'Выдвинутая', '12': 'Средняя', '11': 'Втянутая'}},
#  {'id': '6',
#   'name': 'Выступ подбородка',
#   'values': {'20': 'Срезанный',
#    '21': 'Маловыступающий',
#    '22': 'Средний по выступу',
#    '24': 'Выступающий'}},
#  {'id': '61',
#   'name': 'Мясистость подбородка',
#   'values': {'220': 'Костный', '219': 'Средний ', '218': 'Мясистый'}},
#  {'id': '59',
#   'name': 'Ширина подбородка',
#   'values': {'212': 'Широкий', '213': 'Средний', '214': 'Острый'}},
#  {'id': '58',
#   'name': 'Тяжесть подбородка',
#   'values': {'209': 'Тяжелый',
#    '305': 'Средне-тяжелый',
#    '210': 'Средний',
#    '304': 'Средне-легкий',
#    '211': 'Легкий'}},
#  {'id': '48',
#   'name': 'Асимметрия брови',
#   'values': {'168': 'Левая вверх', '167': 'Нет', '169': 'Правая вверх'}},
#  {'id': '60',
#   'name': 'Форма подбородка',
#   'values': {'215': 'Закругленный', '217': 'Средний', '560': 'Прямоугольный'}},
#  {'id': '29',
#   'name': 'Асимметрия размера глаз',
#   'values': {'191': 'Левый больше',
#    '109': 'Равнозначные',
#    '108': 'Правый больше'}},
#  {'id': '75',
#   'name': 'Асимметрия наклона глаз',
#   'values': {'253': 'Левый', '254': 'Средний', '255': 'Правый'}},
#  {'id': '110',
#   'name': 'Асимметрия век',
#   'values': {'296': 'Атрофия слева',
#    '295': 'Нет асимметрии',
#    '294': 'Атрофия справа'}},
#  {'id': '22',
#   'name': 'Асимметрия носа',
#   'values': {'84': 'Влево', '246': 'Отсутствует', '85': 'Вправо'}},
#  {'id': '13',
#   'name': 'Асимметрия губ',
#   'values': {'49': 'Слитная', '245': 'Средний', '48': 'Лук купидона'}},
#  {'id': '73',
#   'name': 'Асимметрия угла губ',
#   'values': {'242': 'Левый угол вверх',
#    '251': 'Равнозначные',
#    '243': 'Правый угол вверх'}},
#  {'id': '5',
#   'name': 'Асимметрия желваков',
#   'values': {'184': 'Вправо', '321': 'Нет асимметрии', '18': 'Влево'}},
#  {'id': '47',
#   'name': 'Асимметрия челюсти',
#   'values': {'165': 'Вправо', '164': 'Нет', '166': 'Влево'}},
#  {'id': '117',
#   'name': 'Выраженность желваков',
#   'values': {'314': 'Выражены', '315': 'Средние', '316': 'Нет желваков'}},
#  {'id': '7',
#   'name': 'Асимметрия подбородка',
#   'values': {'25': 'Влево', '26': 'Отсутствует', '244': 'Вправо'}},
#  {'id': '142',
#   'name': 'Линия губ',
#   'values': {'532': 'Волнистая', '533': 'Средняя', '561': 'Прямая'}},
#  {'id': '143',
#   'name': 'Полнота обеих губ',
#   'values': {'534': 'Полные', '535': 'Тонкие'}},
#  {'id': '144',
#   'name': 'Контур обеих губ',
#   'values': {'536': 'Четкий', '537': 'Размытый'}},
#  {'id': '145',
#   'name': 'Скос профиля',
#   'values': {'538': 'Низ', '539': 'Верх'}},
#  {'id': '146',
#   'name': 'Акцент профиля',
#   'values': {'540': 'Глаза', '541': 'Нос', '542': 'Губы'}},
#  {'id': '147',
#   'name': 'Направление скул',
#   'values': {'543': 'Прямо', '544': 'В стороны'}}]

# %%
for ind in tqdm(df.index[:]):
    anfas_path = df.loc[ind, 'anfas_path']

    
    # VALIDATE
    if anfas_path != None:
        validateCurl = f'''curl -X POST "http://127.0.0.1:8000/validate?image_type=anfas" -H  "accept: application/json" -H  "Content-Type: multipart/form-data" 
                           -F "image_file=@{anfas_path};type=image/jpeg"'''
        args = shlex.split(validateCurl)
        stdout, stderr = subprocess.Popen(args, shell=False, stdout=subprocess.PIPE, stderr=subprocess.PIPE).communicate()
        anfas_response = json.loads(stdout.decode("UTF-8"))
        
        # Check if anfas was found
        if len(anfas_response) == 1: continue
            
        anfas_bbox = list(anfas_response['bbox'].values())
        anfas_keypoints = list(anfas_response['keypoints'].values())
        head_pose = anfas_response['head_pose']
        
        df.loc[ind, ['anfas_bbox', 'anfas_roll', 'anfas_pitch', 'anfas_yaw', 'anfas_keypoints']] = \
            anfas_bbox, head_pose['roll'], head_pose['pitch'], head_pose['yaw'], anfas_keypoints
        
        anfas_photo_present = True
    else: anfas_photo_present = False
        
    # INSERT
    if anfas_photo_present:
        insertCurl = f'''curl -X POST "http://127.0.0.1:8000/insert_photos?\
person_uuid=12345678-1234-5678-1234-56781234{ind:04d}&force_insert=true\
&service_id=etalon\
&person_name={ind}" -H  "accept: application/json" -H  "Content-Type: multipart/form-data" 
-F "anfas_file=@{anfas_path};type=image/jpeg" 
-F "anfas_bbox={anfas_bbox}" 
-F "anfas_keypoints={anfas_keypoints}" 
'''
        args = shlex.split(insertCurl)
        stdout, stderr = subprocess.Popen(args, shell=False, stdout=subprocess.PIPE, stderr=subprocess.PIPE).communicate()
        insert_response = json.loads(stdout.decode("UTF-8"))
        
        
    # GET FEATURES
    getFeaturesCurl = f"""curl -X 'GET' \
  'http://127.0.0.1:8000/get_features?person_uuid=12345678-1234-5678-1234-56781234{ind:04d}&additional=false' \
  -H 'accept: application/json'"""
    args = shlex.split(getFeaturesCurl)
    stdout, stderr = subprocess.Popen(args, shell=False, stdout=subprocess.PIPE, stderr=subprocess.PIPE).communicate()
    get_features_response = json.loads(stdout.decode("UTF-8"))

    anfas_json = parse_new_merlin_features(get_features_response)
    
    anfas_cat_json = parse_new_merlin_features_cat(get_features_response)

    df.loc[ind, pd.Series(anfas_json).index] = pd.Series(anfas_json).values 
    df.loc[ind, pd.Series(anfas_cat_json).index] = pd.Series(anfas_cat_json).values 
        
df
# Out:
# <ipython-input-21-d609a8f68bc0>:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for ind in tqdm(df.index[:]):
#   0%|          | 0/1515 [00:00<?, ?it/s]
# /home/nikolay/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py:983: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   arr_value = np.array(value)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py:983: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   arr_value = np.array(value)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py:983: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   arr_value = np.array(value)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py:983: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   arr_value = np.array(value)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py:983: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   arr_value = np.array(value)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py:983: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   arr_value = np.array(value)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py:983: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   arr_value = np.array(value)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-d609a8f68bc0> in <module>
#       8                            -F "image_file=@{anfas_path};type=image/jpeg"'''
#       9         args = shlex.split(validateCurl)
# ---> 10         stdout, stderr = subprocess.Popen(args, shell=False, stdout=subprocess.PIPE, stderr=subprocess.PIPE).communicate()
#      11         anfas_response = json.loads(stdout.decode("UTF-8"))
#      12
#
# ~/anaconda3/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1022
#    1023             try:
# -> 1024                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1025             except KeyboardInterrupt:
#    1026                 # https://bugs.python.org/issue25942
#
# ~/anaconda3/lib/python3.8/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1864                             'failed to raise TimeoutExpired.')
#    1865
# -> 1866                     ready = selector.select(timeout)
#    1867                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1868
#
# ~/anaconda3/lib/python3.8/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
df
# Out:
#      Асимметрия челюсти Высота бровей Наклон глаз Полнота верхней губы  \
# 1              0.199763      0.157848   -3.556181             0.674127
# 2              1.406422      0.234049   -9.304257             1.952523
# 3              0.767045       0.14717  -12.548961             1.387937
# 4             -2.437557      0.229279    4.763642             1.624786
# 5              0.361198      0.249773    -3.17983             1.625533
# ...                 ...           ...         ...                  ...
# 3656                NaN           NaN         NaN                  NaN
# 3659                NaN           NaN         NaN                  NaN
# 3660                NaN           NaN         NaN                  NaN
# 3662                NaN           NaN         NaN                  NaN
# 3663                NaN           NaN         NaN                  NaN
#
#      Полнота нижней губы Асимметрия размера глаз Ширина посадки глаз  \
# 1                5.28829                0.958603            0.668852
# 2                4.98833                1.053644            0.775771
# 3               6.477041                0.833423             0.67127
# 4               7.775663                1.047095            0.875444
# 5               5.747126                 1.16487            0.928726
# ...                  ...                     ...                 ...
# 3656                 NaN                     NaN                 NaN
# 3659                 NaN                     NaN                 NaN
# 3660                 NaN                     NaN                 NaN
# 3662                 NaN                     NaN                 NaN
# 3663                 NaN                     NaN                 NaN
#
#          Скулы Форма головы Верхнее веко  ... Оттопыренность ушей cat  \
# 1     -0.69093      1.28122      0.39589  ...                 Средние
# 2    -1.759248     1.469252     0.817019  ...                 Средние
# 3    -8.489522     1.508935     0.413803  ...                 Средние
# 4    -4.069176     1.248573     0.626627  ...                 Средние
# 5    -1.762808     1.334151     0.855537  ...                 Средние
# ...        ...          ...          ...  ...                     ...
# 3656       NaN          NaN          NaN  ...                     NaN
# 3659       NaN          NaN          NaN  ...                     NaN
# 3660       NaN          NaN          NaN  ...                     NaN
# 3662       NaN          NaN          NaN  ...                     NaN
# 3663       NaN          NaN          NaN  ...                     NaN
#
#      Ширина челюсти cat Уголки рта cat Форма бровей cat           anfas_bbox  \
# 1          Средне-узкая          Пряые           Прямые  [99, 127, 301, 380]
# 2        Средне-широкая          Вверх           Прямые  [190, 84, 550, 557]
# 3          Средне-узкая          Пряые            Серпы  [204, 52, 313, 193]
# 4               Средняя           Вниз           Прямые  [198, 59, 329, 224]
# 5          Средне-узкая          Пряые         Полукруг  [186, 63, 308, 228]
# ...                 ...            ...              ...                  ...
# 3656                NaN            NaN              NaN                  NaN
# 3659                NaN            NaN              NaN                  NaN
# 3660                NaN            NaN              NaN                  NaN
# 3662                NaN            NaN              NaN                  NaN
# 3663                NaN            NaN              NaN                  NaN
#
#      anfas_roll anfas_pitch  anfas_yaw  \
# 1     -4.293029   -0.353592 -14.546278
# 2      2.410667   12.497448    -2.1028
# 3     -2.847204   22.061258  -1.491265
# 4     -3.263579   -5.708035  -0.395757
# 5     -3.122562    5.140881   0.091976
# ...         ...         ...        ...
# 3656        NaN         NaN        NaN
# 3659        NaN         NaN        NaN
# 3660        NaN         NaN        NaN
# 3662        NaN         NaN        NaN
# 3663        NaN         NaN        NaN
#
#                                         anfas_keypoints  \
# 1     [[148, 227], [231, 218], [186, 285], [170, 327...
# 2     [[285, 276], [451, 272], [362, 372], [291, 438...
# 3     [[235, 109], [284, 106], [259, 143], [241, 164...
# 4     [[234, 119], [295, 115], [267, 146], [242, 184...
# 5     [[223, 128], [282, 127], [255, 160], [230, 193...
# ...                                                 ...
# 3656                                                NaN
# 3659                                                NaN
# 3660                                                NaN
# 3662                                                NaN
# 3663                                                NaN
#
#                       anfas_path
# 1        data/photos/1_anfas.jpg
# 2        data/photos/2_anfas.jpg
# 3        data/photos/3_anfas.jpg
# 4        data/photos/4_anfas.jpg
# 5        data/photos/5_anfas.jpg
# ...                          ...
# 3656  data/photos/3656_anfas.jpg
# 3659  data/photos/3659_anfas.jpg
# 3660  data/photos/3660_anfas.jpg
# 3662  data/photos/3662_anfas.jpg
# 3663  data/photos/3663_anfas.jpg
#
# [1515 rows x 46 columns]

# %%
anfas_json = {}
if len(get_features_response['anfas_glazomer']) > 0:
    for feature_item in get_features_response['anfas_glazomer']['feature_cat'].items():
        key = feature_item[0]
        value = feature_item[1]

        anfas_json[f'{key} cat'] = value

anfas_json

# %%
get_features_response
# Out:
# {'anfas_glazomer': {'api_result': {'47': 164,
#    '33': 116,
#    '56': 232,
#    '10': 37,
#    '9': 310,
#    '29': 109,
#    '27': 100,
#    '25': 94,
#    '51': 181,
#    '55': 203,
#    '48': 167,
#    '77': 308,
#    '8': 27,
#    '75': 253,
#    '22': 85,
#    '26': 95,
#    '54': 248,
#    '1': 2,
#    '78': 265,
#    '35': 123},
#   'feature_values': {'Асимметрия челюсти': 0.19976260567317006,
#    'Высота бровей': 0.15784817243216748,
#    'Наклон глаз': -3.556181094255109,
#    'Полнота верхней губы': 0.6741273405609765,
#    'Полнота нижней губы': 5.288289944872042,
#    'Асимметрия размера глаз': 0.9586025865388216,
#    'Ширина посадки глаз': 0.6688515849014508,
#    'Скулы': -0.6909300333453761,
#    'Форма головы': 1.2812197889411818,
#    'Верхнее веко': 0.3958897651642835,
#    'Асимметрия брови': 0.15849414486439883,
#    'Наклон бровей': 13.84835914577931,
#    'Размер рта': 30.361204390868735,
#    'Асимметрия наклона глаз': -3.556181094255116,
#    'Асимметрия носа': -4.923832865305664,
#    'Размер глаз': 4.744448039328242,
#    'Оттопыренность ушей': 23.335177173264565,
#    'Ширина челюсти': 0.8841249261369527,
#    'Уголки рта': -6.115503566285407,
#    'Форма бровей': [0.10226384550333023,
#     0.07249586284160614,
#     0.71932452917099,
#     0.10591575503349304]},
#   'feature_cat': {'Асимметрия челюсти': 'Нет асимметрии',
#    'Высота бровей': 'Низкая',
#    'Наклон глаз': 'Средний',
#    'Полнота верхней губы': 'Тонкая',
#    'Полнота нижней губы': 'Средне-тонкая',
#    'Асимметрия размера глаз': 'Без ассиметрии',
#    'Ширина посадки глаз': 'Близко',
#    'Скулы': 'Не выражены',
#    'Форма головы': 'Брахи',
#    'Верхнее веко': 'Выраженные',
#    'Асимметрия брови': 'Нет асимметрии',
#    'Наклон бровей': 'Средние',
#    'Размер рта': 'Маленький',
#    'Асимметрия наклона глаз': 'Левый',
#    'Асимметрия носа': 'Вправо',
#    'Размер глаз': 'Маленькие',
#    'Оттопыренность ушей': 'Средние',
#    'Ширина челюсти': 'Средне-узкая',
#    'Уголки рта': 'Пряые',
#    'Форма бровей': 'Прямые'}},
#  'profile_glazomer': {},
#  'additional': {}}

# %%
df.to_pickle('data/features_df_raw.pkl')

# %%
df
# Out:
#      Асимметрия челюсти Высота бровей Наклон глаз Полнота верхней губы  \
# 1               3.39034      0.155163    -7.74418             0.728999
# 2            0.00993511      0.225912    -9.29231              1.77806
# 3               0.89146      0.141038    -12.1525              1.41409
# 4              -2.40735      0.226568     2.48019              1.53393
# 5                   NaN           NaN         NaN                  NaN
# ...                 ...           ...         ...                  ...
# 3656            1.32788      0.198817    -2.38594              1.41517
# 3659           -5.21102      0.236392     2.72631               1.3934
# 3660            0.47419      0.190069    -6.70984              1.24821
# 3662            2.30704      0.188664      -8.573              1.09228
# 3663           -7.56725      0.180123    -5.80445              1.65061
#
#      Полнота нижней губы Асимметрия размера глаз Ширина посадки глаз  \
# 1                5.31025                0.981586            0.720082
# 2                5.54587                 1.01363            0.817481
# 3                6.59908                0.937218            0.739006
# 4                7.66965                 1.00283            0.859598
# 5                    NaN                     NaN                 NaN
# ...                  ...                     ...                 ...
# 3656             7.07587                 0.79098            0.791811
# 3659              7.3768                 1.16799            0.803615
# 3660             6.24105                0.900908            0.867235
# 3662              5.0413                 0.99628            0.849671
# 3663             6.94996                 1.03956            0.854423
#
#           Скулы Форма головы Верхнее веко  ... Оттопыренность ушей  \
# 1      -1.35369       1.3088     0.349305  ...             24.9942
# 2       -6.8673       1.4838     0.820615  ...             12.2423
# 3    -0.0052002      1.53736     0.550704  ...             18.8545
# 4      -2.44127       1.2525     0.766965  ...             14.5723
# 5           NaN          NaN          NaN  ...                 NaN
# ...         ...          ...          ...  ...                 ...
# 3656    10.1836      1.34451     0.430224  ...             8.64829
# 3659    1.01612      1.52562      1.01696  ...             15.5732
# 3660    16.7626      1.50106     0.398726  ...             21.3979
# 3662    14.3227      1.33605     0.439944  ...             18.4848
# 3663    -11.302      1.49515     0.454881  ...             29.5373
#
#      Ширина челюсти Уголки рта  \
# 1          0.893839   -1.83494
# 2          0.915261    35.5966
# 3          0.886362    9.02179
# 4          0.913848   -11.0368
# 5               NaN        NaN
# ...             ...        ...
# 3656       0.896277   -5.08898
# 3659       0.909806    -87.676
# 3660       0.965543   -2.38594
# 3662       0.941044   -7.14959
# 3663       0.851768    -57.073
#
#                                            Форма бровей            anfas_bbox  \
# 1     [0.06420356780290604, 0.01820863038301468, 0.7...  [102, 132, 298, 375]
# 2     [0.14115186035633087, 0.14609426259994507, 0.6...   [191, 85, 544, 559]
# 3     [0.036605104804039, 0.006168249528855085, 0.41...   [208, 57, 311, 193]
# 4     [0.20367132127285004, 0.17563262581825256, 0.5...   [196, 58, 327, 228]
# 5                                                   NaN                   NaN
# ...                                                 ...                   ...
# 3656  [0.014971252530813217, 0.03858862817287445, 0....   [161, 57, 287, 226]
# 3659  [0.24318234622478485, 0.017631953582167625, 0....   [168, 12, 301, 199]
# 3660  [0.010378898121416569, 0.003601981792598963, 0...   [156, 39, 273, 205]
# 3662  [0.030657710507512093, 0.004682827275246382, 0...   [167, 39, 289, 203]
# 3663  [0.21106207370758057, 0.017282292246818542, 0....   [194, 43, 319, 223]
#
#      anfas_roll anfas_pitch anfas_yaw  \
# 1          -9.5        -8.7       9.7
# 2            -3       -10.7        -9
# 3            -3       -11.7       4.4
# 4          -5.8        -3.6      23.4
# 5           NaN         NaN       NaN
# ...         ...         ...       ...
# 3656       -0.9          -5      25.7
# 3659       -0.9        -2.1     -20.3
# 3660        0.9          -9       6.9
# 3662       -2.4        -7.8       3.2
# 3663       -3.1        -7.9     -13.2
#
#                                         anfas_keypoints  \
# 1     [[149, 229], [231, 217], [188, 281], [171, 329...
# 2     [[284, 275], [452, 271], [364, 368], [293, 444...
# 3     [[235, 109], [284, 107], [260, 142], [241, 165...
# 4     [[231, 119], [296, 116], [266, 147], [241, 187...
# 5                                                   NaN
# ...                                                 ...
# 3656  [[179, 120], [234, 120], [188, 155], [180, 187...
# 3659  [[216, 94], [275, 93], [257, 125], [227, 161],...
# 3660  [[181, 102], [235, 107], [199, 141], [179, 167...
# 3662  [[200, 105], [257, 104], [231, 139], [204, 164...
# 3663  [[236, 120], [293, 115], [277, 160], [251, 189...
#
#                       anfas_path
# 1        data/photos/1_anfas.jpg
# 2        data/photos/2_anfas.jpg
# 3        data/photos/3_anfas.jpg
# 4        data/photos/4_anfas.jpg
# 5        data/photos/5_anfas.jpg
# ...                          ...
# 3656  data/photos/3656_anfas.jpg
# 3659  data/photos/3659_anfas.jpg
# 3660  data/photos/3660_anfas.jpg
# 3662  data/photos/3662_anfas.jpg
# 3663  data/photos/3663_anfas.jpg
#
# [1515 rows x 26 columns]
