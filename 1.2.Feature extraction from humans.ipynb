# %%
import subprocess
import shlex
import json
import pandas as pd
from glob import glob
from tqdm import tqdm_notebook as tqdm
import uuid
import os
import cv2

# %%
folder_path = 'data/photos/'
photos = os.listdir(folder_path)[:]
photo_ids = set([i.split('_')[0] for i in photos])
photo_ids
# Out:
# {'347',
#  '1330',
#  '33',
#  '132',
#  '1602',
#  '1255',
#  '338',
#  '374',
#  '1159',
#  '597',
#  '485',
#  '1220',
#  '676',
#  '3629',
#  '283',
#  '1150',
#  '429',
#  '215',
#  '883',
#  '1050',
#  '344',
#  '3623',
#  '711',
#  '291',
#  '979',
#  '451',
#  '519',
#  '775',
#  '86',
#  '1072',
#  '1078',
#  '1117',
#  '1349',
#  '673',
#  '81',
#  '641',
#  '363',
#  '851',
#  '3662',
#  '1416',
#  '742',
#  '73',
#  '561',
#  '941',
#  '120',
#  '918',
#  '477',
#  '876',
#  '1250',
#  '1282',
#  '133',
#  '605',
#  '1414',
#  '1351',
#  '1384',
#  '368',
#  '969',
#  '512',
#  '556',
#  '1214',
#  '3630',
#  '1187',
#  '1340',
#  '361',
#  '1500',
#  '965',
#  '3636',
#  '679',
#  '1274',
#  '476',
#  '1057',
#  '1380',
#  '917',
#  '562',
#  '1305',
#  '1310',
#  '3633',
#  '1123',
#  '3650',
#  '649',
#  '433',
#  '12',
#  '1088',
#  '660',
#  '1382',
#  '1224',
#  '66',
#  '1264',
#  '1197',
#  '150',
#  '950',
#  '100',
#  '31',
#  '3412',
#  '648',
#  '80',
#  '685',
#  '210',
#  '167',
#  '166',
#  '932',
#  '414',
#  '737',
#  '1383',
#  '893',
#  '1265',
#  '430',
#  '1438',
#  '303',
#  '469',
#  '388',
#  '91',
#  '671',
#  '455',
#  '1317',
#  '204',
#  '581',
#  '504',
#  '496',
#  '529',
#  '609',
#  '1418',
#  '1016',
#  '1022',
#  '1920',
#  '70',
#  '315',
#  '1100',
#  '3660',
#  '424',
#  '522',
#  '369',
#  '1176',
#  '226',
#  '1032',
#  '199',
#  '14',
#  '88',
#  '480',
#  '647',
#  '836',
#  '1828',
#  '570',
#  '51',
#  '360',
#  '129',
#  '857',
#  '541',
#  '1135',
#  '186',
#  '3434',
#  '299',
#  '232',
#  '128',
#  '229',
#  '1674',
#  '1120',
#  '152',
#  '403',
#  '1069',
#  '458',
#  '1276',
#  '1010',
#  '659',
#  '114',
#  '1427',
#  '481',
#  '687',
#  '1286',
#  '588',
#  '627',
#  '235',
#  '1320',
#  '1218',
#  '362',
#  '234',
#  '859',
#  '978',
#  '1229',
#  '174',
#  '233',
#  '909',
#  '3626',
#  '342',
#  '68',
#  '574',
#  '956',
#  '1166',
#  '1410',
#  '1315',
#  '428',
#  '973',
#  '1402',
#  '925',
#  '1052',
#  '1157',
#  '242',
#  '3648',
#  '495',
#  '302',
#  '43',
#  '1099',
#  '415',
#  '208',
#  '1084',
#  '901',
#  '1172',
#  '3627',
#  '222',
#  '1251',
#  '1212',
#  '209',
#  '1272',
#  '769',
#  '127',
#  '447',
#  '1347',
#  '586',
#  '262',
#  '715',
#  '95',
#  '1348',
#  '250',
#  '502',
#  '583',
#  '557',
#  '1144',
#  '931',
#  '607',
#  '1439',
#  '3396',
#  '371',
#  '1026',
#  '740',
#  '510',
#  '1119',
#  '589',
#  '278',
#  '871',
#  '181',
#  '1206',
#  '376',
#  '241',
#  '768',
#  '981',
#  '220',
#  '3531',
#  '748',
#  '310',
#  '501',
#  '200',
#  '1141',
#  '89',
#  '712',
#  '1028',
#  '1109',
#  '1367',
#  '37',
#  '381',
#  '138',
#  '1271',
#  '943',
#  '1136',
#  '77',
#  '936',
#  '930',
#  '3401',
#  '1334',
#  '441',
#  '293',
#  '115',
#  '412',
#  '273',
#  '1019',
#  '1405',
#  '1287',
#  '263',
#  '1379',
#  '140',
#  '270',
#  '264',
#  '384',
#  '425',
#  '437',
#  '636',
#  '183',
#  '710',
#  '745',
#  '792',
#  '1130',
#  '840',
#  '629',
#  '1377',
#  '953',
#  '625',
#  '117',
#  '899',
#  '169',
#  '1237',
#  '1143',
#  '1149',
#  '551',
#  '156',
#  '3646',
#  '591',
#  '569',
#  '989',
#  '432',
#  '60',
#  '1537',
#  '692',
#  '32',
#  '275',
#  '113',
#  '1175',
#  '3637',
#  '160',
#  '252',
#  '58',
#  '356',
#  '1111',
#  '1662',
#  '670',
#  '1280',
#  '295',
#  '526',
#  '1081',
#  '85',
#  '520',
#  '947',
#  '804',
#  '1194',
#  '416',
#  '1436',
#  '705',
#  '1395',
#  '383',
#  '8',
#  '905',
#  '1042',
#  '638',
#  '1127',
#  '802',
#  '1433',
#  '3',
#  '47',
#  '1234',
#  '1058',
#  '158',
#  '195',
#  '1344',
#  '1366',
#  '994',
#  '1071',
#  '1268',
#  '736',
#  '1293',
#  '398',
#  '962',
#  '1260',
#  '860',
#  '771',
#  '370',
#  '1926',
#  '1164',
#  '1328',
#  '503',
#  '980',
#  '812',
#  '513',
#  '963',
#  '305',
#  '850',
#  '763',
#  '3404',
#  '593',
#  '92',
#  '717',
#  '124',
#  '175',
#  '767',
#  '506',
#  '1343',
#  '1106',
#  '71',
#  '739',
#  '1442',
#  '1449',
#  '185',
#  '298',
#  '1273',
#  '444',
#  '613',
#  '177',
#  '662',
#  '224',
#  '914',
#  '672',
#  '1923',
#  '394',
#  '903',
#  '896',
#  '487',
#  '1390',
#  '239',
#  '494',
#  '1345',
#  '754',
#  '1077',
#  '10',
#  '1021',
#  '314',
#  '919',
#  '1318',
#  '276',
#  '41',
#  '592',
#  '442',
#  '42',
#  '755',
#  '752',
#  '460',
#  '1158',
#  '36',
#  '964',
#  '223',
#  '483',
#  '1244',
#  '1792',
#  '677',
#  '1327',
#  '1927',
#  '54',
#  '1412',
#  '1353',
#  '121',
#  '456',
#  '280',
#  '192',
#  '1198',
#  '461',
#  '38',
#  '462',
#  '237',
#  '473',
#  '839',
#  '580',
#  '678',
#  '3656',
#  '1393',
#  '550',
#  '563',
#  '1369',
#  '1386',
#  '137',
#  '1096',
#  '734',
#  '1098',
#  '144',
#  '466',
#  '427',
#  '353',
#  '1409',
#  '1329',
#  '633',
#  '726',
#  '1118',
#  '364',
#  '34',
#  '191',
#  '1919',
#  '1407',
#  '747',
#  '892',
#  '1191',
#  '1038',
#  '151',
#  '886',
#  '333',
#  '162',
#  '131',
#  '1193',
#  '1311',
#  '1365',
#  '35',
#  '1594',
#  '45',
#  '1025',
#  '827',
#  '774',
#  '590',
#  '1079',
#  '669',
#  '1942',
#  '340',
#  '530',
#  '1207',
#  '558',
#  '998',
#  '1174',
#  '1210',
#  '982',
#  '665',
#  '1047',
#  '1485',
#  '308',
#  '691',
#  '1400',
#  '744',
#  '157',
#  '820',
#  '906',
#  '1153',
#  '454',
#  '1073',
#  '853',
#  '277',
#  '1104',
#  '536',
#  '821',
#  '1269',
#  '1391',
#  '817',
#  '334',
#  '959',
#  '624',
#  '1319',
#  '3632',
#  '797',
#  '970',
#  '373',
#  '644',
#  '219',
#  '630',
#  '616',
#  '1215',
#  '856',
#  '1731',
#  '301',
#  '1163',
#  '1387',
#  '807',
#  '1303',
#  '206',
#  '475',
#  '3654',
#  '1306',
#  '1325',
#  '825',
#  '300',
#  '355',
#  '511',
#  '1350',
#  '1357',
#  '1061',
#  '722',
#  '435',
#  '163',
#  '1388',
#  '877',
#  '1429',
#  '407',
#  '967',
#  '1289',
#  '1064',
#  '977',
#  '417',
#  '796',
#  '3615',
#  '749',
#  '422',
#  '564',
#  '996',
#  '946',
#  '1807',
#  '626',
#  '350',
#  '995',
#  '701',
#  '688',
#  '640',
#  '1219',
#  '1181',
#  '93',
#  '697',
#  '780',
#  '101',
#  '76',
#  '63',
#  '397',
#  '3619',
#  '991',
#  '399',
#  '318',
#  '1354',
#  '1165',
#  '1385',
#  '508',
#  '306',
#  '927',
#  '309',
#  '1352',
#  '900',
#  '858',
#  '173',
#  '585',
#  '1196',
#  '1450',
#  '467',
#  '1074',
#  '1371',
#  '1110',
#  '911',
#  '684',
#  '1114',
#  '258',
#  '211',
#  '134',
#  '1065',
#  '1036',
#  '1921',
#  '1001',
#  '816',
#  '565',
#  '546',
#  '1121',
#  '499',
#  '656',
#  '1035',
#  '702',
#  '793',
#  '284',
#  '491',
#  '329',
#  '1430',
#  '1008',
#  '1131',
#  '395',
#  '1126',
#  '75',
#  '814',
#  '598',
#  '90',
#  '231',
#  '3392',
#  '321',
#  '632',
#  '3659',
#  '635',
#  '572',
#  '668',
#  '1173',
#  '327',
#  '1059',
#  '449',
#  '328',
#  '724',
#  '1253',
#  '516',
#  '1476',
#  '62',
#  '553',
#  '322',
#  '681',
#  '3635',
#  '1428',
#  '1298',
#  '533',
#  '1168',
#  '52',
#  '908',
#  '1023',
#  '431',
#  '1479',
#  '457',
#  '617',
#  '1401',
#  '1226',
#  '1277',
#  '401',
#  '874',
#  '1361',
#  '992',
#  '1092',
#  '255',
#  '1202',
#  '1443',
#  '1221',
#  '94',
#  '316',
#  '1053',
#  '1444',
#  '1376',
#  '975',
#  '147',
#  '1389',
#  '560',
#  '1211',
#  '1108',
#  '443',
#  '643',
#  '1048',
#  '645',
#  '658',
#  '753',
#  '830',
#  '582',
#  '341',
#  '106',
#  '1161',
#  '835',
#  '1431',
#  '505',
#  '683',
#  '869',
#  '577',
#  '1199',
#  '78',
#  '1027',
#  '725',
#  '389',
#  '1156',
#  '1009',
#  '841',
#  '1137',
#  '667',
#  '1148',
#  '862',
#  '666',
#  '993',
#  '809',
#  '482',
#  '1068',
#  '1018',
#  '1105',
#  '731',
#  '895',
#  '372',
#  '1408',
#  '1102',
#  '594',
#  '789',
#  '890',
#  '130',
#  '3652',
#  '3405',
#  '392',
#  '1107',
#  '1417',
#  '484',
#  '928',
#  '922',
#  '654',
#  '48',
#  '230',
#  '1241',
#  '1129',
#  '323',
#  '236',
#  '682',
#  '1083',
#  '1145',
#  '661',
#  '1321',
#  '888',
#  '759',
#  '3625',
#  '1419',
#  '61',
#  '1',
#  '540',
#  '178',
#  '1003',
#  '1918',
#  '324',
#  '332',
#  '102',
#  '1300',
#  '1323',
#  '1204',
#  '902',
#  '786',
#  '110',
#  '1290',
#  '159',
#  '354',
#  '655',
#  '268',
#  '67',
#  '838',
#  '161',
#  '74',
#  '929',
#  '612',
#  '584',
#  '521',
#  '196',
#  '1326',
#  '1000',
#  '826',
#  '1335',
#  '1134',
#  '1333',
#  '735',
#  '706',
#  '319',
#  '939',
#  '404',
#  '728',
#  '555',
#  '1928',
#  '1565',
#  '942',
#  '1230',
#  '1049',
#  '7',
#  '379',
#  '1248',
#  '325',
#  '1167',
#  '878',
#  '3639',
#  '26',
#  '142',
#  '478',
#  '545',
#  '881',
#  '217',
#  '834',
#  '1270',
#  '951',
#  '760',
#  '1020',
#  '123',
#  '576',
#  '201',
#  '518',
#  '1179',
#  '615',
#  '1489',
#  '806',
#  '985',
#  '709',
#  '193',
#  '935',
#  '436',
#  '46',
#  '1457',
#  '621',
#  '1547',
#  '824',
#  '1943',
#  '1339',
#  '79',
#  '805',
#  '916',
#  '448',
#  '1227',
#  '486',
#  '1240',
#  '149',
#  '375',
#  '188',
#  '387',
#  '517',
#  '1247',
#  '1190',
#  '1051',
#  '3653',
#  '3642',
#  '148',
#  '408',
#  '358',
#  '287',
#  '1398',
#  '139',
#  '618',
#  '999',
#  '1201',
#  '197',
#  '1422',
#  '847',
#  '650',
#  '221',
#  '743',
#  '579',
#  '136',
#  '446',
#  '109',
#  '1239',
#  '3427',
#  '254',
#  '25',
#  '1259',
#  '1007',
#  '187',
#  '176',
#  '898',
#  '3470',
#  '611',
#  '703',
#  '1887',
#  '64',
#  '3414',
#  '531',
#  '1070',
#  '56',
#  '57',
#  '849',
#  '411',
#  '1076',
#  '686',
#  '385',
#  '406',
#  '420',
#  '1245',
#  '203',
#  '290',
#  '1154',
#  '396',
#  '663',
#  '1033',
#  '1646',
#  '282',
#  '326',
#  '29',
#  '1223',
#  '1275',
#  '1116',
#  '746',
#  '1396',
#  '153',
#  '44',
#  '1488',
#  '1043',
#  '1246',
#  '253',
#  '652',
#  '799',
#  '1262',
#  '1424',
#  '390',
#  '1238',
#  '800',
#  '604',
#  '28',
#  '921',
#  '320',
#  '84',
#  '165',
#  '887',
#  '3640',
#  '955',
#  '1060',
#  '465',
#  '1217',
#  '861',
#  '1363',
#  '228',
#  '1045',
#  '413',
#  '1178',
#  '600',
#  '1423',
#  '1184',
#  '514',
#  '16',
#  '405',
#  '972',
#  '974',
#  '179',
#  '766',
#  '573',
#  '1155',
#  '674',
#  '566',
#  '154',
#  '1066',
#  '345',
#  '1162',
#  '225',
#  '634',
#  '646',
#  '3397',
#  '336',
#  '1014',
#  '83',
#  '1284',
#  '257',
#  '367',
#  '1189',
#  '23',
#  '788',
#  '708',
#  '452',
#  '1368',
#  '6',
#  '1208',
#  '27',
#  '9',
#  ...}

# %%
# Reformat all files to .jpg
# for i in tqdm(glob('data/photos/*')):
#     try:
#         img = cv2.imread(i)
#         img.shape
#         os.remove(i)
#         new_name = i.split('.')[0]+'.jpg'
#         cv2.imwrite(new_name, img)
#     except:
#         print(i)

# %%
folder_path = 'data/humans/*'
photos = glob(folder_path)

merlin_feature_keys = ['Асимметрия челюсти', 'Высота бровей', 'Наклон глаз', 'Полнота верхней губы', 'Полнота нижней губы', 'Асимметрия размера глаз', 'Ширина посадки глаз', 'Скулы', 'Форма головы', 'Верхнее веко', 'Асимметрия брови', 'Наклон бровей', 'Размер рта', 'Асимметрия наклона глаз', 'Асимметрия носа', 'Размер глаз', 'Оттопыренность ушей', 'Ширина челюсти', 'Уголки рта', 'Форма бровей']
merlin_feature_cat_keys = [i + ' cat' for i in merlin_feature_keys] 

df = pd.DataFrame(columns=merlin_feature_keys + merlin_feature_cat_keys +
                  ['anfas_bbox', 'anfas_roll', 'anfas_pitch', 'anfas_yaw', 'anfas_keypoints'])

df['anfas_path'] = photos
df
# Out:
#      Асимметрия челюсти Высота бровей Наклон глаз Полнота верхней губы  \
# 0                   NaN           NaN         NaN                  NaN
# 1                   NaN           NaN         NaN                  NaN
# 2                   NaN           NaN         NaN                  NaN
# 3                   NaN           NaN         NaN                  NaN
# 4                   NaN           NaN         NaN                  NaN
# ...                 ...           ...         ...                  ...
# 1731                NaN           NaN         NaN                  NaN
# 1732                NaN           NaN         NaN                  NaN
# 1733                NaN           NaN         NaN                  NaN
# 1734                NaN           NaN         NaN                  NaN
# 1735                NaN           NaN         NaN                  NaN
#
#      Полнота нижней губы Асимметрия размера глаз Ширина посадки глаз Скулы  \
# 0                    NaN                     NaN                 NaN   NaN
# 1                    NaN                     NaN                 NaN   NaN
# 2                    NaN                     NaN                 NaN   NaN
# 3                    NaN                     NaN                 NaN   NaN
# 4                    NaN                     NaN                 NaN   NaN
# ...                  ...                     ...                 ...   ...
# 1731                 NaN                     NaN                 NaN   NaN
# 1732                 NaN                     NaN                 NaN   NaN
# 1733                 NaN                     NaN                 NaN   NaN
# 1734                 NaN                     NaN                 NaN   NaN
# 1735                 NaN                     NaN                 NaN   NaN
#
#      Форма головы Верхнее веко  ... Оттопыренность ушей cat  \
# 0             NaN          NaN  ...                     NaN
# 1             NaN          NaN  ...                     NaN
# 2             NaN          NaN  ...                     NaN
# 3             NaN          NaN  ...                     NaN
# 4             NaN          NaN  ...                     NaN
# ...           ...          ...  ...                     ...
# 1731          NaN          NaN  ...                     NaN
# 1732          NaN          NaN  ...                     NaN
# 1733          NaN          NaN  ...                     NaN
# 1734          NaN          NaN  ...                     NaN
# 1735          NaN          NaN  ...                     NaN
#
#      Ширина челюсти cat Уголки рта cat Форма бровей cat anfas_bbox anfas_roll  \
# 0                   NaN            NaN              NaN        NaN        NaN
# 1                   NaN            NaN              NaN        NaN        NaN
# 2                   NaN            NaN              NaN        NaN        NaN
# 3                   NaN            NaN              NaN        NaN        NaN
# 4                   NaN            NaN              NaN        NaN        NaN
# ...                 ...            ...              ...        ...        ...
# 1731                NaN            NaN              NaN        NaN        NaN
# 1732                NaN            NaN              NaN        NaN        NaN
# 1733                NaN            NaN              NaN        NaN        NaN
# 1734                NaN            NaN              NaN        NaN        NaN
# 1735                NaN            NaN              NaN        NaN        NaN
#
#      anfas_pitch anfas_yaw anfas_keypoints                   anfas_path
# 0            NaN       NaN             NaN      data/humans/23377_1.jpg
# 1            NaN       NaN             NaN       data/humans/3557_1.jpg
# 2            NaN       NaN             NaN  data/humans/wild_0569_1.jpg
# 3            NaN       NaN             NaN  data/humans/wild_0487_1.jpg
# 4            NaN       NaN             NaN      data/humans/15863_1.jpg
# ...          ...       ...             ...                          ...
# 1731         NaN       NaN             NaN      data/humans/22326_1.jpg
# 1732         NaN       NaN             NaN       data/humans/4012_1.jpg
# 1733         NaN       NaN             NaN  data/humans/wild_0503_1.jpg
# 1734         NaN       NaN             NaN      data/humans/23381_1.jpg
# 1735         NaN       NaN             NaN       data/humans/4088_1.jpg
#
# [1736 rows x 46 columns]

# %%
def parse_new_merlin_features(response):
    anfas_json = {}
    if len(response['anfas_glazomer']) > 0:
        for feature_item in response['anfas_glazomer']['feature_values'].items():
            key = feature_item[0]
            value = feature_item[1]
            
            anfas_json[key] = value
            
    return anfas_json

def parse_new_merlin_features_cat(response):
    anfas_json = {}
    if len(response['anfas_glazomer']) > 0:
        for feature_item in response['anfas_glazomer']['feature_cat'].items():
            key = feature_item[0]
            value = feature_item[1]
            anfas_json[f'{key} cat'] = value
            
    return anfas_json
        
with open('/home/nikolay/workspace/Merlin/merlin/supl/api_feature.json') as f:
    features = json.load(f)
features
# Out:
# [{'id': '72',
#   'name': 'Профиль',
#   'values': {'240': 'Иррац', '241': 'Средний', '239': 'Рац'}},
#  {'id': '71',
#   'name': 'Затылок',
#   'values': {'238': 'Скошен', '250': 'Средний', '237': 'Выражен'}},
#  {'id': '57',
#   'name': 'Шея',
#   'values': {'206': 'Короткая', '207': 'Средняя', '208': 'Длинная'}},
#  {'id': '53',
#   'name': 'Доминирующая зона лица ',
#   'values': {'195': 'Нижняя',
#    '196': 'Средняя',
#    '197': 'Верхняя',
#    '247': 'Равнозначные',
#    '297': 'Верхняя и нижняя',
#    '298': 'Верхняя и средняя',
#    '299': 'Средняя и нижняя'}},
#  {'id': '51',
#   'name': 'Форма головы',
#   'values': {'181': 'Брахицефал', '182': 'Мезоцефал', '183': 'Долихоцефал'}},
#  {'id': '40',
#   'name': 'Линия волос',
#   'values': {'144': 'Ментально-оценочная',
#    '145': 'Ментально-системная',
#    '146': 'Телесно-оценочная',
#    '147': 'Телесно-системная'}},
#  {'id': '38',
#   'name': 'Зоны лба',
#   'values': {'135': 'Центр', '136': 'Не выражены', '137': 'Периферия'}},
#  {'id': '37',
#   'name': 'Скос лба',
#   'values': {'130': 'Скошенный',
#    '131': 'Средне-скошенный',
#    '132': 'Средне-прямой',
#    '133': 'Прямой',
#    '134': 'Выпуклый'}},
#  {'id': '36',
#   'name': 'Надбровные дуги',
#   'values': {'129': 'Выражены',
#    '128': 'Средне-выражены',
#    '127': 'Не выражены'}},
#  {'id': '35',
#   'name': 'Форма бровей',
#   'values': {'123': 'Прямые',
#    '124': 'Серпом',
#    '125': 'Изломом',
#    '126': 'Полукруглые'}},
#  {'id': '33',
#   'name': 'Высота посадки бровей',
#   'values': {'116': 'Низкие',
#    '117': 'Средне-низкие',
#    '118': 'Средние по высоте',
#    '119': 'Средне-высокие',
#    '120': 'Высокие'}},
#  {'id': '31',
#   'name': 'Густота бровей',
#   'values': {'112': 'Густые', '177': 'Cредне выражены', '113': 'Не выражены'}},
#  {'id': '77',
#   'name': 'Наклон бровей',
#   'values': {'262': 'Атакующие',
#    '308': 'Средние',
#    '261': 'Без наклона',
#    '260': 'Домиком'}},
#  {'id': '26',
#   'name': 'Размер глаз',
#   'values': {'99': 'Большие',
#    '98': 'Средне-большие',
#    '97': 'Средние',
#    '96': 'Средне-маленькие',
#    '95': 'Маленькие'}},
#  {'id': '56',
#   'name': 'Наклон глаз',
#   'values': {'204': 'Вверх', '232': 'Без наклона', '205': 'Вниз'}},
#  {'id': '27',
#   'name': 'Ширина посадки глаз',
#   'values': {'100': 'Близко посажены',
#    '101': 'Средняя посадка',
#    '102': 'Далеко посажены'}},
#  {'id': '55',
#   'name': 'Верхнее веко',
#   'values': {'201': 'Гипертонус', '203': 'Выраженные', '202': 'Опущенные'}},
#  {'id': '46',
#   'name': 'Выпуклость глаз',
#   'values': {'160': 'Выпуклые',
#    '161': 'Средне-выпуклые',
#    '313': 'Средние по выпуклости',
#    '162': 'Средне-впалые',
#    '163': 'Впалые'}},
#  {'id': '28',
#   'name': 'Глубина посадки глаз',
#   'values': {'105': 'Неглубоко', '104': 'Средне', '103': 'Глубоко '}},
#  {'id': '24',
#   'name': 'Впалость переносицы',
#   'values': {'91': 'Прямая',
#    '306': 'Средне-прямая',
#    '173': 'Cредняя',
#    '307': 'Средне-впалая',
#    '92': 'Впалая'}},
#  {'id': '17',
#   'name': 'Высота носа',
#   'values': {'63': 'Низкий',
#    '64': 'Средне-низкий',
#    '65': 'Средний по высоте',
#    '66': 'Средне-высокий',
#    '67': 'Высокий'}},
#  {'id': '19',
#   'name': 'Длина носа',
#   'values': {'73': 'Короткий',
#    '74': 'Средне-короткий',
#    '75': 'Средний по длине',
#    '76': 'Средне-длинный',
#    '77': 'Длинный'}},
#  {'id': '20',
#   'name': 'Наклон носа',
#   'values': {'80': 'Вздернутый', '79': 'Близко к среднему', '78': 'Опущеный'}},
#  {'id': '18',
#   'name': 'Ширина носа',
#   'values': {'72': 'Широкий',
#    '71': 'Средне-широкий',
#    '70': 'Средний по ширине',
#    '69': 'Средне-узкий',
#    '68': 'Узкий'}},
#  {'id': '23',
#   'name': 'Ширина переносицы',
#   'values': {'90': 'Широкая',
#    '89': 'Средне-широкая',
#    '88': 'Средняя по ширине',
#    '87': 'Средне-узкая',
#    '86': 'Узкая'}},
#  {'id': '21',
#   'name': 'Ширина ноздрей',
#   'values': {'83': 'Широкие', '82': 'Средние', '81': 'Узкие'}},
#  {'id': '39',
#   'name': 'Размер ушей',
#   'values': {'139': 'Маленькие',
#    '523': 'Средне-маленькие',
#    '141': 'Средние по размеру',
#    '524': 'Средне-большие',
#    '143': 'Большие'}},
#  {'id': '54',
#   'name': 'Оттопыренность ушей',
#   'values': {'198': 'Прижатые', '248': 'Средние', '200': 'Оттопыренные'}},
#  {'id': '25',
#   'name': 'Скулы',
#   'values': {'93': 'Выражены', '174': 'Cредне выражены', '94': 'Не выражены'}},
#  {'id': '15',
#   'name': 'Высота желобка',
#   'values': {'59': 'Высокий', '57': 'Средний по высоте', '55': 'Низкий'}},
#  {'id': '14',
#   'name': 'Ширина желобка',
#   'values': {'54': 'Широкий', '52': 'Средний по ширине', '50': 'Узкий'}},
#  {'id': '16',
#   'name': 'Глубина желобка',
#   'values': {'60': 'Отсутствует',
#    '61': 'Средний по глубине',
#    '62': 'Глубокий'}},
#  {'id': '11',
#   'name': 'Доминантность губ',
#   'values': {'42': 'Верхняя доминанта',
#    '44': 'Равнозначные',
#    '43': 'Нижняя доминанта'}},
#  {'id': '8',
#   'name': 'Размер рта',
#   'values': {'31': 'Большой',
#    '312': 'Средне-большой',
#    '29': 'Средний',
#    '311': 'Средне-маленький',
#    '27': 'Маленький'}},
#  {'id': '9',
#   'name': 'Полнота нижней губы',
#   'values': {'32': 'Тонкая',
#    '310': 'Средне-тонкая',
#    '34': 'Средняя',
#    '309': 'Средне-полная',
#    '36': 'Полная'}},
#  {'id': '10',
#   'name': 'Полнота верхней губы',
#   'values': {'41': 'Полная',
#    '317': 'Средне-полная',
#    '39': 'Средняя',
#    '318': 'Средне-тонкая',
#    '37': 'Тонкая'}},
#  {'id': '50',
#   'name': 'Контур нижней губы',
#   'values': {'178': 'Размытый', '179': 'Средне-четкий', '180': 'Четкий'}},
#  {'id': '70',
#   'name': 'Контур верхней губы',
#   'values': {'228': 'Размытый', '229': 'Средне-четкий', '230': 'Четкий'}},
#  {'id': '78',
#   'name': 'Уголки губ',
#   'values': {'263': 'Уголки вниз',
#    '265': 'Уголки прямые',
#    '264': 'Уголки вверх'}},
#  {'id': '1',
#   'name': 'Ширина челюсти',
#   'values': {'1': 'Узкая',
#    '2': 'Средне-узкая',
#    '3': 'Средняя по ширине',
#    '4': 'Средне-широкая',
#    '5': 'Широкая'}},
#  {'id': '4',
#   'name': 'Угол челюсти',
#   'values': {'17': 'Прямой',
#    '16': 'Средне-прямой',
#    '15': 'Плавный',
#    '14': 'Отсутствует'}},
#  {'id': '2',
#   'name': 'Тяжесть челюсти',
#   'values': {'10': 'Тяжелая',
#    '9': 'Средне-тяжелая',
#    '8': 'Средняя по тяжести',
#    '7': 'Средне-легкая',
#    '6': 'Легкая'}},
#  {'id': '3',
#   'name': 'Выдвинутость челюсти',
#   'values': {'13': 'Выдвинутая', '12': 'Средняя', '11': 'Втянутая'}},
#  {'id': '6',
#   'name': 'Выступ подбородка',
#   'values': {'20': 'Срезанный',
#    '21': 'Маловыступающий',
#    '22': 'Средний по выступу',
#    '24': 'Выступающий'}},
#  {'id': '61',
#   'name': 'Мясистость подбородка',
#   'values': {'220': 'Костный', '219': 'Средний ', '218': 'Мясистый'}},
#  {'id': '59',
#   'name': 'Ширина подбородка',
#   'values': {'212': 'Широкий', '213': 'Средний', '214': 'Острый'}},
#  {'id': '58',
#   'name': 'Тяжесть подбородка',
#   'values': {'209': 'Тяжелый',
#    '305': 'Средне-тяжелый',
#    '210': 'Средний',
#    '304': 'Средне-легкий',
#    '211': 'Легкий'}},
#  {'id': '48',
#   'name': 'Асимметрия брови',
#   'values': {'168': 'Левая вверх', '167': 'Нет', '169': 'Правая вверх'}},
#  {'id': '60',
#   'name': 'Форма подбородка',
#   'values': {'215': 'Закругленный', '217': 'Средний', '560': 'Прямоугольный'}},
#  {'id': '29',
#   'name': 'Асимметрия размера глаз',
#   'values': {'191': 'Левый больше',
#    '109': 'Равнозначные',
#    '108': 'Правый больше'}},
#  {'id': '75',
#   'name': 'Асимметрия наклона глаз',
#   'values': {'253': 'Левый', '254': 'Средний', '255': 'Правый'}},
#  {'id': '110',
#   'name': 'Асимметрия век',
#   'values': {'296': 'Атрофия слева',
#    '295': 'Нет асимметрии',
#    '294': 'Атрофия справа'}},
#  {'id': '22',
#   'name': 'Асимметрия носа',
#   'values': {'84': 'Влево', '246': 'Отсутствует', '85': 'Вправо'}},
#  {'id': '13',
#   'name': 'Асимметрия губ',
#   'values': {'49': 'Слитная', '245': 'Средний', '48': 'Лук купидона'}},
#  {'id': '73',
#   'name': 'Асимметрия угла губ',
#   'values': {'242': 'Левый угол вверх',
#    '251': 'Равнозначные',
#    '243': 'Правый угол вверх'}},
#  {'id': '5',
#   'name': 'Асимметрия желваков',
#   'values': {'184': 'Вправо', '321': 'Нет асимметрии', '18': 'Влево'}},
#  {'id': '47',
#   'name': 'Асимметрия челюсти',
#   'values': {'165': 'Вправо', '164': 'Нет', '166': 'Влево'}},
#  {'id': '117',
#   'name': 'Выраженность желваков',
#   'values': {'314': 'Выражены', '315': 'Средние', '316': 'Нет желваков'}},
#  {'id': '7',
#   'name': 'Асимметрия подбородка',
#   'values': {'25': 'Влево', '26': 'Отсутствует', '244': 'Вправо'}},
#  {'id': '142',
#   'name': 'Линия губ',
#   'values': {'532': 'Волнистая', '533': 'Средняя', '561': 'Прямая'}},
#  {'id': '143',
#   'name': 'Полнота обеих губ',
#   'values': {'534': 'Полные', '535': 'Тонкие'}},
#  {'id': '144',
#   'name': 'Контур обеих губ',
#   'values': {'536': 'Четкий', '537': 'Размытый'}},
#  {'id': '145',
#   'name': 'Скос профиля',
#   'values': {'538': 'Низ', '539': 'Верх'}},
#  {'id': '146',
#   'name': 'Акцент профиля',
#   'values': {'540': 'Глаза', '541': 'Нос', '542': 'Губы'}},
#  {'id': '147',
#   'name': 'Направление скул',
#   'values': {'543': 'Прямо', '544': 'В стороны'}}]

# %%
for ind in tqdm(df.index[:]):
    anfas_path = df.loc[ind, 'anfas_path']

    
    # VALIDATE
    if anfas_path != None:
        validateCurl = f'''curl -X POST "http://127.0.0.1:8000/validate?image_type=anfas" -H  "accept: application/json" -H  "Content-Type: multipart/form-data" 
                           -F "image_file=@{anfas_path};type=image/jpeg"'''
        args = shlex.split(validateCurl)
        stdout, stderr = subprocess.Popen(args, shell=False, stdout=subprocess.PIPE, stderr=subprocess.PIPE).communicate()
        anfas_response = json.loads(stdout.decode("UTF-8"))
        
        # Check if anfas was found
        if len(anfas_response) == 1: continue
            
        anfas_bbox = list(anfas_response['bbox'].values())
        anfas_keypoints = list(anfas_response['keypoints'].values())
        head_pose = anfas_response['head_pose']
        
        df.loc[ind, ['anfas_bbox', 'anfas_roll', 'anfas_pitch', 'anfas_yaw', 'anfas_keypoints']] = \
            anfas_bbox, head_pose['roll'], head_pose['pitch'], head_pose['yaw'], anfas_keypoints
        
        anfas_photo_present = True
    else: anfas_photo_present = False
        
    # INSERT
    if anfas_photo_present:
        insertCurl = f'''curl -X POST "http://127.0.0.1:8000/insert_photos?\
person_uuid=12345678-1234-5678-1234-56781234{ind:04d}&force_insert=true\
&service_id=etalon\
&person_name={ind}" -H  "accept: application/json" -H  "Content-Type: multipart/form-data" 
-F "anfas_file=@{anfas_path};type=image/jpeg" 
-F "anfas_bbox={anfas_bbox}" 
-F "anfas_keypoints={anfas_keypoints}" 
'''
        args = shlex.split(insertCurl)
        stdout, stderr = subprocess.Popen(args, shell=False, stdout=subprocess.PIPE, stderr=subprocess.PIPE).communicate()
        insert_response = json.loads(stdout.decode("UTF-8"))
        
        
    # GET FEATURES
    getFeaturesCurl = f"""curl -X 'GET' \
  'http://127.0.0.1:8000/get_features?person_uuid=12345678-1234-5678-1234-56781234{ind:04d}&additional=false' \
  -H 'accept: application/json'"""
    args = shlex.split(getFeaturesCurl)
    stdout, stderr = subprocess.Popen(args, shell=False, stdout=subprocess.PIPE, stderr=subprocess.PIPE).communicate()
    get_features_response = json.loads(stdout.decode("UTF-8"))

    anfas_json = parse_new_merlin_features(get_features_response)
    anfas_cat_json = parse_new_merlin_features_cat(get_features_response)

    df.loc[ind, pd.Series(anfas_json).index] = pd.Series(anfas_json).values 
    df.loc[ind, pd.Series(anfas_cat_json).index] = pd.Series(anfas_cat_json).values 
        
df
# Out:
# <ipython-input-6-71a1c8f513e8>:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for ind in tqdm(df.index[:]):
#   0%|          | 0/1736 [00:00<?, ?it/s]
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ...
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /home/nikolay/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
#      Асимметрия челюсти Высота бровей Наклон глаз Полнота верхней губы  \
# 0              0.988846       0.15922   -8.425621             1.094285
# 1              1.871214      0.215812   -4.792105             1.911358
# 2              1.332272      0.181547    0.834696             1.074225
# 3              0.002513      0.217783  -16.706118             2.378289
# 4              1.690925       0.26829    3.405016             1.182935
# ...                 ...           ...         ...                  ...
# 1731          -4.743319       0.15997  -12.518257             0.676581
# 1732           -3.51717      0.277768   -5.068018             2.166255
# 1733           2.583132      0.197724  -10.422874             1.140166
# 1734           6.999978      0.224875     0.68206              1.13801
# 1735           0.390769       0.20438    -6.12435             0.695087
#
#      Полнота нижней губы Асимметрия размера глаз Ширина посадки глаз  \
# 0               4.748783                0.975209            0.870956
# 1               8.148659                 0.96075            0.882226
# 2               4.187657                1.042565            0.765917
# 3               8.548309                 1.03886            0.845905
# 4               4.611398                0.977412              0.7858
# ...                  ...                     ...                 ...
# 1731            5.936575                1.066776            0.826851
# 1732            8.317798                1.010103            0.942079
# 1733            9.679354                0.959467             0.91263
# 1734            4.355265                0.976121            0.714384
# 1735            5.319303                0.973223            0.858393
#
#           Скулы Форма головы Верхнее веко  ... Оттопыренность ушей cat  \
# 0        9.4999      1.53017     0.440973  ...                 Средние
# 1      8.098112     1.689316      0.66232  ...                 Средние
# 2     13.727596     1.323815     0.415507  ...                 Средние
# 3      4.128904     1.299686     0.574022  ...            Оттопыренные
# 4      2.416031     1.368557     0.768447  ...                 Средние
# ...         ...          ...          ...  ...                     ...
# 1731   8.034751     1.343466     0.348165  ...                Прижатые
# 1732   0.021125     1.536128      1.02716  ...                Прижатые
# 1733   6.698992     1.459632     0.367528  ...                Прижатые
# 1734  21.841788     1.393747     0.599271  ...                 Средние
# 1735    1.22061     1.490418     0.641085  ...                Прижатые
#
#      Ширина челюсти cat Уголки рта cat Форма бровей cat            anfas_bbox  \
# 0          Средне-узкая          Пряые           Прямые  [150, 198, 660, 876]
# 1        Средне-широкая          Вверх           Прямые   [80, 88, 730, 1024]
# 2          Средне-узкая          Пряые           Прямые   [74, 172, 635, 993]
# 3          Средне-узкая          Вверх            Излом   [63, 111, 656, 948]
# 4        Средне-широкая          Вверх           Прямые   [7, 104, 680, 1008]
# ...                 ...            ...              ...                   ...
# 1731       Средне-узкая          Вверх            Серпы  [147, 334, 641, 991]
# 1732       Средне-узкая          Пряые         Полукруг  [168, 240, 669, 914]
# 1733       Средне-узкая          Вверх            Серпы  [89, 145, 695, 1031]
# 1734     Средне-широкая          Вверх         Полукруг   [73, 125, 653, 926]
# 1735       Средне-узкая          Пряые           Прямые  [116, 234, 646, 929]
#
#      anfas_roll anfas_pitch anfas_yaw  \
# 0          -2.3        -7.1      -2.6
# 1          -0.9        -5.5      -0.1
# 2          -1.4        -9.0      -5.8
# 3          -0.0       -12.7      -0.3
# 4          -5.8        -5.8       0.1
# ...         ...         ...       ...
# 1731        0.5       -10.7      -3.8
# 1732       -0.4        -7.8      -1.6
# 1733       -3.0       -11.6       2.9
# 1734       -2.2        -6.0       2.2
# 1735       -0.0        -9.5      -0.9
#
#                                         anfas_keypoints  \
# 0     [[291, 444], [527, 451], [415, 607], [314, 715...
# 1     [[251, 471], [544, 465], [409, 652], [286, 822...
# 2     [[227, 501], [493, 510], [372, 679], [253, 798...
# 3     [[228, 444], [512, 456], [365, 650], [252, 763...
# 4     [[196, 471], [502, 459], [351, 634], [231, 794...
# ...                                                 ...
# 1731  [[292, 590], [530, 603], [405, 753], [285, 822...
# 1732  [[310, 526], [535, 525], [417, 649], [329, 767...
# 1733  [[241, 505], [531, 498], [382, 703], [285, 846...
# 1734  [[263, 443], [505, 448], [388, 612], [273, 739...
# 1735  [[276, 532], [515, 534], [385, 686], [289, 795...
#
#                        anfas_path
# 0         data/humans/23377_1.jpg
# 1          data/humans/3557_1.jpg
# 2     data/humans/wild_0569_1.jpg
# 3     data/humans/wild_0487_1.jpg
# 4         data/humans/15863_1.jpg
# ...                           ...
# 1731      data/humans/22326_1.jpg
# 1732       data/humans/4012_1.jpg
# 1733  data/humans/wild_0503_1.jpg
# 1734      data/humans/23381_1.jpg
# 1735       data/humans/4088_1.jpg
#
# [1736 rows x 46 columns]

# %%
df.to_pickle('data/humans_df_raw2.pkl')

# %%
df
# Out:
#      Асимметрия челюсти Высота бровей Наклон глаз Полнота верхней губы  \
# 0              0.988846       0.15922    -8.42562              1.09428
# 1               1.87121      0.215812     -4.7921              1.91136
# 2               1.33227      0.181547    0.834696              1.07423
# 3             0.0025133      0.217783    -16.7061              2.37829
# 4               1.69093       0.26829     3.40502              1.18294
# ...                 ...           ...         ...                  ...
# 1731           -4.74332       0.15997    -12.5183             0.676581
# 1732           -3.51717      0.277768    -5.06802              2.16626
# 1733            2.58313      0.197724    -10.4229              1.14017
# 1734            6.99998      0.224875     0.68206              1.13801
# 1735           0.390769       0.20438    -6.12435             0.695087
#
#      Полнота нижней губы Асимметрия размера глаз Ширина посадки глаз  \
# 0                4.74878                0.975209            0.870956
# 1                8.14866                 0.96075            0.882226
# 2                4.18766                 1.04256            0.765917
# 3                8.54831                 1.03886            0.845905
# 4                 4.6114                0.977412              0.7858
# ...                  ...                     ...                 ...
# 1731             5.93657                 1.06678            0.826851
# 1732              8.3178                  1.0101            0.942079
# 1733             9.67935                0.959467             0.91263
# 1734             4.35526                0.976121            0.714384
# 1735              5.3193                0.973223            0.858393
#
#           Скулы Форма головы Верхнее веко  ... Оттопыренность ушей  \
# 0        9.4999      1.53017     0.440973  ...             18.7887
# 1       8.09811      1.68932      0.66232  ...              15.928
# 2       13.7276      1.32382     0.415507  ...               20.21
# 3        4.1289      1.29969     0.574022  ...             24.2853
# 4       2.41603      1.36856     0.768447  ...             13.8265
# ...         ...          ...          ...  ...                 ...
# 1731    8.03475      1.34347     0.348165  ...             4.77587
# 1732  0.0211249      1.53613      1.02716  ...              4.8139
# 1733    6.69899      1.45963     0.367528  ...             12.2924
# 1734    21.8418      1.39375     0.599271  ...             20.1484
# 1735    1.22061      1.49042     0.641085  ...             10.2219
#
#      Ширина челюсти Уголки рта  \
# 0          0.873776   -2.02136
# 1          0.932415    4.03625
# 2          0.863298   0.468321
# 3          0.854595    17.6822
# 4          0.942014    5.19443
# ...             ...        ...
# 1731       0.872903      28.49
# 1732       0.866637  0.0980372
# 1733       0.853945    5.80673
# 1734       0.927516    8.58503
# 1735       0.891357  -0.674037
#
#                                            Форма бровей            anfas_bbox  \
# 0     [0.04731930047273636, 0.026797650381922722, 0....  [150, 198, 660, 876]
# 1     [0.08665512502193451, 0.24548573791980743, 0.6...   [80, 88, 730, 1024]
# 2     [0.2599807381629944, 0.005138075444847345, 0.5...   [74, 172, 635, 993]
# 3     [0.5780298709869385, 0.005794493947178125, 0.0...   [63, 111, 656, 948]
# 4     [0.06523028761148453, 0.030243486166000366, 0....   [7, 104, 680, 1008]
# ...                                                 ...                   ...
# 1731  [0.3095841407775879, 0.011759256012737751, 0.0...  [147, 334, 641, 991]
# 1732  [0.028288042172789574, 0.5972376465797424, 0.0...  [168, 240, 669, 914]
# 1733  [0.017856692895293236, 0.00030670620617456734,...  [89, 145, 695, 1031]
# 1734  [0.1370871365070343, 0.643079400062561, 0.0550...   [73, 125, 653, 926]
# 1735  [0.08155816048383713, 0.0006139111355878413, 0...  [116, 234, 646, 929]
#
#      anfas_roll anfas_pitch anfas_yaw  \
# 0          -2.3        -7.1      -2.6
# 1          -0.9        -5.5      -0.1
# 2          -1.4          -9      -5.8
# 3            -0       -12.7      -0.3
# 4          -5.8        -5.8       0.1
# ...         ...         ...       ...
# 1731        0.5       -10.7      -3.8
# 1732       -0.4        -7.8      -1.6
# 1733         -3       -11.6       2.9
# 1734       -2.2          -6       2.2
# 1735         -0        -9.5      -0.9
#
#                                         anfas_keypoints  \
# 0     [[291, 444], [527, 451], [415, 607], [314, 715...
# 1     [[251, 471], [544, 465], [409, 652], [286, 822...
# 2     [[227, 501], [493, 510], [372, 679], [253, 798...
# 3     [[228, 444], [512, 456], [365, 650], [252, 763...
# 4     [[196, 471], [502, 459], [351, 634], [231, 794...
# ...                                                 ...
# 1731  [[292, 590], [530, 603], [405, 753], [285, 822...
# 1732  [[310, 526], [535, 525], [417, 649], [329, 767...
# 1733  [[241, 505], [531, 498], [382, 703], [285, 846...
# 1734  [[263, 443], [505, 448], [388, 612], [273, 739...
# 1735  [[276, 532], [515, 534], [385, 686], [289, 795...
#
#                        anfas_path
# 0         data/humans/23377_1.jpg
# 1          data/humans/3557_1.jpg
# 2     data/humans/wild_0569_1.jpg
# 3     data/humans/wild_0487_1.jpg
# 4         data/humans/15863_1.jpg
# ...                           ...
# 1731      data/humans/22326_1.jpg
# 1732       data/humans/4012_1.jpg
# 1733  data/humans/wild_0503_1.jpg
# 1734      data/humans/23381_1.jpg
# 1735       data/humans/4088_1.jpg
#
# [1736 rows x 26 columns]
